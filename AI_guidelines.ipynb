# %% [markdown]
# ## Structure

# %% [markdown]
# ### xx00*.ipynb files
# - xx00.ipynb is the chapter landing, should include:
#     - one paragraph chapter intro with some (3-5) bullet points of the most essential concepts as part of the intro
#     - one video for one of the most important concepts of the chapter introfor the chapter, and
# - leaning goals
# - chapter table of contents
# - chapter glossary.
#
# ### chapter content sections
# - do an outline of ## and ### for each section
# - the outline (and the headings) should not be underlined
#
# ```text
# +--------------------------------------+
# | Outline                              |
# |                                      |
# | What is Functional Programming?      |
# | Pure Functions & Immutability        |
# |   o Pure functions                   |
# |   o Immutability                     |
# | First-Class Functions & Lambda       |
# | Higher-Order Functions               |
# |   o Decorators                       |
# |   o Common Built-in Decorators       |
# | Summary                              |
# +--------------------------------------+
#
# 13.1.1. What is Functional Programming?
# No underline. Use normal heading text color, not bright link blue.
# ```
# ### assignment section
# - preview questions
# - homework questions
# - lab assignment

# %% [markdown]
# ## Context

# %% [markdown]
# - This is a college level textbook for an intermediate to advanced Python programming with data science as the context.
# - Computer science concepts are important
# - Some math doesn't hurt, especially when demonstrated mathematically.
# - Stay current with the industry
# - I want my students to be able to prepare for technical interviews after taking my class.

# %% [markdown]
# ## Reviewing Content

# %% [markdown]
# 1. Always show diffs
# 3. Computer science/information technology/data science cases are also useful
# 4. Use fruits (apple, banana, cherry), names (alice, bob, charlie), nums(1, 2, 3, 4, 5) when simple datasets work better.
# 5. Use business/management datasets when appropriate
# 6. (reuse the same datasets across chapters)
# 7. Is the structure sound? Are sections well organized?
# 8. Are all important topics included?
# 9. Are there topics that should be removed and moved to other chapters?

# %% [markdown]
# ## Lecture Organization (Agreed Rules)
#
# - Students use the Jupyter Book outline to understand the section structure, so outline clarity is a priority.
# - Keep top-level section count to 5 or fewer `##` headings in each notebook whenever possible.
# - Use `**Learning Goals**` (bold text), not a `## Learning goals` heading.
# - Do not add a `## Setup` section; import cells can appear at the beginning without a heading.
# - Avoid `## Why ... Matter` style headings in lecture notebooks.
# - This semester: place one exercise at the end of each subsection (`##` or `###`).
# - Next semester: move exercises into one dedicated exercise section per notebook.

# %% [markdown]
# ## Assignments
# The 3 types of assignments (preview, lab, review) for each chapter should show in the Jupyter Book left menu as Assignments at the end of each chapter.

# %% [markdown]
# ## Creating Exercise

# %% [markdown]
# - create exercises for each ## or ### (the ones with essential content) heading.
# - questions should be simple as practice of the content section just learned.
# - place each exercise at the end of the ### section.
# - each question has 2 code cells: one question/input cell and one solution cell.
# - the question cell has metadata tag "thebe-interactive" and the solution cell "hide-input".
# - the CH00-*-intro.ipynb files should not have exercises.

# %% [markdown]
# An example of exercise is as follows. Note the use of ### and # for formatting the question and solution.

# %%
### Exercise: Score Evaluation Script
#   1. Write a Python script that asks the user to input a numerical 
#      score (0-100). 
#   2. Based on that score, the program should print a specific message.
#   3. If the score is 90 or above, print: "Excellent! You got an A."
#   4. If the score is between 70 and 89, print: "Good job! You passed."
#   5. If the score is below 70, print: "Keep practicing! Try again."
### Your code starts here.





### Your code ends here.

# %%
### Solution
# score = int(input("Enter a numerical score (0-100): ") or "99")
score = 99   ### for testing; replace with input() for actual use

if score > 100 or score < 0:
    print("Invalid score. Please enter a value between 0 and 100.")
elif score >= 90:
    print("Excellent! You got an A.")
elif score >= 70:
    print("Good job! You passed.")
else:
    print("Keep practicing! Try again.")
# Out:
# Excellent! You got an A.

# %% [markdown]
# ## Topic List Example:
#
# from sqlalchemy import Operators
#
#
# Introduction
# - What lists are (ordered, mutable collections)
# - Difference between lists vs. tuples vs. sets
# - Creating a list (literals [], list() constructor, list assignment)
#
# Basic Operators
# - Indexing (mylist[0], mylist[-1])
# - Slicing (mylist[1:4], mylist[::-1])
# - Length with len()
# - Iterating through lists (for loops, while loops)
#
# Adding & Removing Elements
# - append(), insert(), extend()
# - remove(), pop(), del
# - Clearing a list (clear())
#
# Searching & Checking
# - Membership (in, not in)
# - index(), count()
#
# Updating Elements
# - Assigning by index (mylist[2] = "newvalue")
# - Assigning slices (mylist[1:3] = [7, 8])
#
# Useful List Methods
# - Sorting: sort() vs. sorted()
# - Reversing: reverse()
# - Copying: copy(), slicing ([:]), list()
#
# Advanced Usage
# - Nested lists (2D lists, accessing inner lists)
# - List comprehensions (with conditions)
# - Combining lists (+, * operators)
# - zip() with lists
# - Built-in functions: min(), max(), sum()
#
# Common Pitfalls
# - Mutable vs immutable behavior
# - Copy vs reference (aliasing)
# - Lists of lists (shallow vs deep copies)
#
# Practice Ideas
# - Create a shopping list program
# - Reverse a list manually (without reverse())
# - Find the largest number in a list
# - Flatten a nested list
# - Build a list comprehension that squares only even numbers
