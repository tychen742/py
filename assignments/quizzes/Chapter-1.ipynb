# %% [markdown]
# #                                              Chapter 1 Quiz

# %% [markdown]
# ### **Question 1**
#
# **What is the output of the following code?**
# ```python
# print(5 + 2 * 3 ** 2)

# %% [markdown]
# ### **Question 2**
#
# **The code below is supposed to multiply the variable quantity by 3. However, it produces an incorrect output. Find the bug and correct the line of code.**
# ```python
# # Initial buggy code
# quantity = '4'
# print(quantity * 3)

# %% [markdown]
# ### **Question 3**
#
# **Is this the correct way to calculate the square of a number in Python? if yes, write "Yes, this is the correct way in the below cell. "If not, correct the line of code to produce the expected output.**
# ```python
# a = 7 ^ 2
# print(a)

# %% [markdown]
# ### **Question 4**
#
# **what is the final output of the following code?**
# ```python
# print(2 ** 3 ** 2)

# %% [markdown]
# ### **Question 5**
#
# **Determine the final value and its data type for the following line of code.**
# ```python
# round( (7 ^ 2 * 6) + 1.5 )  # value: ______ ; type: ______
# int('126') / 3              # value: ______ ; type: ______
# print(85 // 2)              # value: ______ ; type: ______
# print(85 / 2)               # value: ______ ; type: ______
