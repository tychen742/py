# %% [markdown]
# #                                              Chapter 4 Quiz

# %% [markdown]
# ### **Question 1**
#
#  Draw a square. Improve the code on the left by rewriting it using a function and write it on the right.
#
# ---
#
# #### Code to Improve
#
# ```python
# import turtle/jupyturtle as t
#
# t.forward(10)
# t.left(90)
# t.forward(100)
# t.left(90)
# t.forward(100)
# t.left(90)
# t.forward(100)
# t.left(90)
# t.forward(100)
#
# t.mainloop()

# %% [markdown]
# ### **Question 2**
#
#   Draw a Triangle. Improve the code on the left by rewriting it using a function and write it on the right.
#
# ---
#
# #### Code to Improve
#
# ```python
# import turtle/jupyturtle as t
#
# t.forward(100)
# t.left(120)
# t.forward(100)
# t.left(120)
# t.forward(100)
#
# t.mainloop()
