# %% [markdown]
# #                                              Chapter 4 Quiz

# %%
### install upon need
# %pip install jupyturtle --quiet

from jupyturtle import *      ### instead of import functions one-by-one

# %% [markdown]
# ## Question 1. Square
#
#  - Onsite Student: Draw a square. Improve the code on the left by rewriting it using a function and write it on the right.
#  - Online Student: Use the online student cell below the next cell
#
# ### Code to Improve
# The import line of the code below is not meant to work.

# %%
import turtle/jupyturtle as t

t.forward(10)
t.left(90)
t.forward(100)
t.left(90)
t.forward(100)
t.left(90)
t.forward(100)
t.left(90)
t.forward(100)

t.mainloop()     ### keeping the graphics window open

# %%
### online studnet answer here ###

# %% [markdown]
# ## Question 2. Triangle
#
# Draw a Triangle. Improve the code on the left by rewriting it using a function and write it on the right.
# - Onsite Student: Draw a square. Improve the code on the left by rewriting it using a function and write it on the right.
# - Online Student: Use the online student cell below the next cell
#
# ### Code to Improve
# The import line of the code below is not meant to work.

# %%
import turtle/jupyturtle as t

t.forward(100)
t.left(120)
t.forward(100)
t.left(120)
t.forward(100)

t.mainloop()     ### keeping the graphics window open

# %%
### online studnet answer here ###

# %% [markdown]
# ## Question 3. Polygon
#
# Design a function that draws regular polygons with a given number of sides and side length. For example, `polygon(7, 30)` would produce a polygon below the code you will produce here:

# %%
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 180,75 198.7,51.5 192,22.3 165,9.3 138,22.3 131.3,51.5 150,75" />'
#
# <g transform="rotate(270.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Question 4. Spike
#
# **Extra-credit!!**

# %% [markdown]
# ![image.png](attachment:00905c5f-1fcd-4d76-8743-d94928bc2828.png)

# %%
##### code here for spike #####
