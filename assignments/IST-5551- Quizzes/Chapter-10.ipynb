# %% [markdown]
# #                                              Chapter 10 Quiz

# %% [markdown]
# ### Read the instructions for each step. On your answer sheet, write the full Python code required to complete each step.

# %% [markdown]
# ### Question 1:
#
# Create a new dictionary variable called `grades`. Add `'Alice'` as a key with the value `85`, and `'Bob'` as a key with the value `92`.

# %%
# Out:
# {'Alice': 85, 'Bob': 92}

# %% [markdown]
# ### Question 2:
# You have the following dictionary
# ```python
# student_logins = {
#     'Aneesh Kolakaluri': 'akbw4',
#     'Christopher Ratliff': 'carm5p',
#     'Karthikeya Thallam': 'kt9m3',
#     'Yuhao Wu': 'ywk59'
# }

# %% [markdown]
# Write code to check if the name 'Yuhao Wu' is in the student_logins dictionary.

# %% [markdown]
# Write the correct code to check if the Login ID 'carm5p' is present in the values of the student_logins dictionary.

# %% [markdown]
# ### Question 3:
# Write a for loop to iterate through the student_logins dictionary and print each Name (key) on its own line.

# %% [markdown]
# ### Question 4:
#
# The following function counts the occurrences of letters in a string. What is the output of the final line?
# ```python
# def value_counts(string):
#     counter = {}
#     for letter in string:
#         if letter not in counter:
#             counter[letter] = 1
#         else:
#             counter[letter] += 1
#     return counter
#
# print(value_counts('brontosaurus'))

# %% [markdown]
# ### Question 5:
#
# The code below uses a dictionary known as a memo to store computed Fibonacci numbers. What is the output of the final line?
# ```python
# known = {0: 0, 1: 1} # This is the memo
#
# def fibonacci_memo(n):
#     if n in known:
#         return known[n]
#
#     res = fibonacci_memo(n-1) + fibonacci_memo(n-2)
#     known[n] = res
#     return res
#
# print(fibonacci_memo(3))
