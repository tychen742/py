# %% [markdown]
# ### **Question 1**
#
# **What is the output of the following code?**
# ```python
# print(5 + 2 * 3 ** 2)

# %% [markdown]
# ### Question 2
#
# **Determine the final value and its data type for the following line of code.**
# ```python
# round( (7 ^ 2 * 6) + 1.5 )  # value: ______ ; type: ______
# int('126') / 3              # value: ______ ; type: ______
# print(85 // 2)              # value: ______ ; type: ______
# print(85 / 2)               # value: ______ ; type: ______

# %% [markdown]
# ### Question 3
#
#
# ```python
# def repeat(word, n):
#     print(word * n)
#
# spam = 'Spam, '
# repeat(spam, 4)

# %% [markdown]
# ### Question 4
#
#
# ```python
#
# def last_three_lines():
#     repeat(spam, 2)
#     print('(Lovely Spam, Wonderful Spam!)')
#     repeat(spam, 2)
#
# last_three_lines()

# %% [markdown]
# ### Question 5
#
# ```python
# import turtle/jupyturtle as t
#
# t.forward(10)
# t.left(90)
# t.forward(100)
# t.left(90)
# t.forward(100)
# t.left(90)
# t.forward(100)
# t.left(90)
# t.forward(100)
#
# t.mainloop()     ### keeping the graphics window open

# %% [markdown]
# ### Question 6
#
#
# ```python
# score = 85
#
# if score >= 90:
#     print("A")
# elif score >= 70:
#     print("B")
# elif score >= 80:
#     print("C")
# else:
#     print("D")

# %% [markdown]
# ### Question 7
#
#
# ```python
#
# def absolute_value_wrong(x):
#     if x < 0:
#         return -x
#     if x > 0:
#         return x
#
# result = absolute_value_wrong(0)
# print(result)

# %% [markdown]
# ### Question 8
# This program tries to count all the words in a list. What is the final output?
#
#
# ```python
# word_list = ['aa', 'aah', 'aal', 'aalii']
# total = 0
#
# for word in word_list:
#     total += 1
#
# print(total)

# %% [markdown]
# ### Question 9
# What is the output of this code? **Hint: Mutable vs Immutable**
#
# ```python
# greeting = 'Hello, world!'
# greeting[0] = 'J'
# print(greeting)

# %% [markdown]
# ### Question 10
#
# 1.  Create an list variable, call it "lst". "lst" should have elements from 0 to 9:
