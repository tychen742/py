# %% [markdown]
# #                                              Chapter 11 Quiz

# %% [markdown]
# ### Question 1:
#
# Write code to create a tuple named `t` containing the letters `'l'`, `'u'`, `'p'`, `'i'`, and `'n'`.

# %%
# Out:
# ('l', 'u', 'p', 'i', 'n')

# %%
t[0]
# Out:
# 'l'

# %% [markdown]
# ### Question 2:
#
# Write the output of the folllowing code

# %%
t1 = ('p',)
type(t1)

# %%
t2 = ('p')
type(t2)

# %% [markdown]
# ### Question 3:
#
# The split() method returns a list. Write a single line of code that uses tuple assignment to split the email address 'monty@python.org' at the '@' symbol and assign the two parts to variables named username and domain.

# %% [markdown]
# ### Question 4:
# The zip() function is used to pair elements from two sequences. Given the two lists: letters = 'abc' numbers = range(3)
#
# Write code that uses zip() and dict() to create a dictionary named letter_map that maps the letters to the numbers. Print letter_map.

# %%
# Out:
# {'a': 0, 'b': 1, 'c': 2}

# %% [markdown]
# ### Question 5:
#
# The sorted() function can take a key argument. Given the following list and helper function:
# ```python
# items = [('b', 1), ('a', 3), ('n', 2)]
#
# def second_element(t):
#     return t[1]
#
# Write code to sort items based on the second element of each tuple (the number), and print the resulting list.

# %%
# Out:
# [('b', 1), ('n', 2), ('a', 3)]
