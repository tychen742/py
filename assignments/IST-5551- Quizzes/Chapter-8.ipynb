# %% [markdown]
# #                                              Chapter 8 Quiz

# %% [markdown]
# ### Question 1:
# What is the output of this code? **Hint: Indexing vs. Length**
#
# ```python
# fruit = 'banana'
# n = len(fruit)
# print(fruit[n])

# %% [raw]
# A) 'a'   B) 'b'      C) IndexError: string index out of range     D) TypeError: string indices must be integers

# %% [markdown]
# ### Question 2:
# What is the output of this code? **Hint: Mutable vs Immutable**
#
# ```python
# greeting = 'Hello, world!'
# greeting[0] = 'J'
# print(greeting)

# %% [raw]
# A) Jello, world!                     B) Hello, world!
# C) J                                 D) TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### Question 3:
#
# What is the output of this code?
# ```python
# word = 'Pineapple'
#
# if word < 'banana':
#     print(word, 'comes before banana.')
# elif word > 'banana':
#     print(word, 'comes after banana.')
# else:
#     print('All right, banana.')

# %% [markdown]
# ### Question 4:
# What is the output of this code?
#
# ```python
# import re
#
# text = "I am Dracula; and I bid you welcome, Mr. Harker, to my house."
# pattern = 'Count'
# result = re.search(pattern, text)
#
# print(result)

# %% [raw]
# A) <re.Match object; span=(0, 5), match='Count'>         B) False
# C) None                                                  D) IndexError: substring not found

# %% [markdown]
# ### Question 5:
# The code below is intended to print the word 'banana' in all uppercase letters. However, when you run it, it still prints `banana`.This happens because strings are immutable, which means they cannot be changed. The word.upper() method doesn't modify the original word string; How would you modify the code so that it correctly prints BANANA?
#
# ```python
# word = 'banana'
# word.upper()
# print(word)
