# %% [markdown]
# #                                              Chapter 5 Quiz

# %% [markdown]
# ### Question 1: Operators & Precedence
#
# What is the final output of the following code?
#
# ```python
# #
# a = 157
# b = 10
# c = 4
# result = a // b % c
# print(result)

# %% [markdown]
# ### Question 2: Chained Conditionals
#
#
# ```python
# score = 85
#
# if score >= 90:
#     print("A")
# elif score >= 70:
#     print("B")
# elif score >= 80:
#     print("C")
# else:
#     print("D")

# %% [markdown]
# ### Question 3: Recursion
#
# What is the output of the following function calls?
#
# ```python
# def countdown_by_two(n):
#     if n == 0:
#         print('Blastoff!')
#     else:
#         print(n)
#         countdown_by_two(n-2)
#
# countdown_by_two(4) # answer -
#
# countdown_by_two(3) # answer -

# %% [markdown]
# ### Question 4: Input and Types
#
# What is the output of this code if the user types 8 and presses Enter?
#
# ```python
# age = input("What is your age? ")
#
# if age > 18:
#     print("Adult")
# else:
#     print("Minor")

# %% [markdown]
# ### Question 5: Recursion
#
# What is the full output of this program?
#
# ```python
# def print_reverse(n):
#     if n > 0:
#         print_reverse(n - 1)
#         print(n)
#
# print_reverse(5)
