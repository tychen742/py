# %% [markdown]
# #                                              Chapter 6 Quiz

# %% [markdown]
# ### Question 1:
#
# What is the output of the final line of this code i.e. **print(a)**?
#
# ```python
# def print_area(r):
#     print(r * r * 3.14)
#
# def return_area(r):
#     return r * r * 3.14
#
# a = print_area(10)
# b = return_area(10)
#
# print(a)

# %% [raw]
# A) 314.0           B) None
#
# C) 0.0             D) NameError

# %% [markdown]
# ### Question 2:
#
# What is the output of this code?
#
# ```python
#
# def absolute_value_wrong(x):
#     if x < 0:
#         return -x
#     if x > 0:
#         return x
#
# result = absolute_value_wrong(0)
# print(result)

# %% [markdown]
# ### Question 3:
#
# What is the full output of this code?
#
# ```python
# def is_divisible(x, y):
#     return x % y == 0
#
# if is_divisible(6, 3) == True:
#     print("A")
#
# if is_divisible(6, 4) == False:
#     print("B")
#
# if is_divisible(5, 2):
#     print("C")

# %%
def is_divisible(x, y):
    return x % y == 0

if is_divisible(6, 3) == True:
    print("A")

if is_divisible(6, 4) == False:
    print("B")

if is_divisible(5, 2):
    print("C")
# Out:
# A
# B

# %% [markdown]
# ### Question 4:
#
# What is the single line of output from this program?
# ```python
#
# def fibonacci(n):
#     if n == 0:
#         return 0
#     elif n == 1:
#         return 1
#     else:
#         return fibonacci(n-1) + fibonacci(n-2)
#
# print(fibonacci(4))

# %%
def fibonacci(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fibonacci(n-1) + fibonacci(n-2)

print(fibonacci(4))
# Out:
# 3

# %%
f(3) + f(2) == f(2) + f(1) + f(1) + f(0) == f(1) + f(0) + f(1) + f(1) + f(0)

# %% [markdown]
# ### Question 5:
#
# What happens when this code is run?
# ```python
# def factorial(n):
#     if n == 0:
#         return 1
#     else:
#         return n * factorial(n-1)
#
# print(factorial(1.5))

# %% [raw]
# A) 1               B) None
#
# C) ValueError      D) RecursionError

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)

print(factorial(1.5))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[5], line 7
#       4     else:
#       5         return n * factorial(n-1)
# ----> 7 print(factorial(1.5))
#
# Cell In[5], line 5, in factorial(n)
#       3     return 1
#       4 else:
# ----> 5     return n * factorial(n-1)
#
# Cell In[5], line 5, in factorial(n)
#       3     return 1
#       4 else:
# ----> 5     return n * factorial(n-1)
#
#     [... skipping similar frames: factorial at line 5 (2975 times)]
#
# Cell In[5], line 5, in factorial(n)
#       3     return 1
#       4 else:
# ----> 5     return n * factorial(n-1)
#
# RecursionError: maximum recursion depth exceeded

# %%
5 * f(4) == 5 * 4 * f(3) == 5 * 4 * 3 * f(2) == 5 * 4 * 3 * 2 * 1
