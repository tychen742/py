# %% [markdown]
# #                                              Chapter 13 Quiz

# %% [markdown]
# ### Question 1:
#
# Write a single line of code using the os module to correctly join the following parts into a single, cross-platform path: 'photos', 'jan-2023', and 'photo1.jpg'. Print the resulting path.

# %%
import os

# %%
                                                                                   ##write your answer here
# Out:
# photos/jan-2023/photo1.jpg

# %% [markdown]
# ### Question 2:
# You are given two variables: num_years = 1.5 num_camels = 23
#
# Write a single line of code using an f-string to create and print the exact string: 'In 1.5 years I have spotted 23 camels'

# %%
num_years = 1.5
num_camels = 23
                                                                                                ##write your answer here
# Out:
# In 1.5 years I have spotted 23 camels

# %% [markdown]
# ### Question 3:
# The code below tries to append a new word ('tops') to a list that is stored in a shelve database, but it does so incorrectly. What is the output of the final print(db[key]) line?

# %%
import shelve
db = shelve.open('anagram_map', 'n') # 'n' creates a new, empty shelf

key = 'opst'
word = 'pots'
db[key] = [word]

# This is the INCORRECT way
db[key].append('tops') 

print(db[key])
db.close()

# %% [markdown]
# ### Question 4:
# Based on the problem in Question 3, write the correct lines of code to:
#
# Read the list from db[key] into a new variable anagram_list.
#
# Append the new word ('tops') to anagram_list.
#
# Write the modified anagram_list back into the database at db[key].
#
# (Assume db, key, and word are already defined from the code in Q4).

# %% [markdown]
# ### Question 5:
#
# Write Python code to:
#
# Open the file 'photos/jan-2023/photo1.jpg' in binary read mode ('rb').
#
# Read all of its content into a variable named data1.
#
# Print the type() of the data1 variable.
