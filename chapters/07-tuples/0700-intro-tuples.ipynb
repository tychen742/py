# %% [markdown]
# # Tuples

# %% [markdown]
# This chapter introduces tuples, a built-in sequence type, and shows how tuples work alongside lists and dictionaries.
#
# - Tuples as immutable sequences
# - Tuple creation with literals, packing, and constructors
# - Indexing, slicing, and unpacking
# - Tuple-aware built-ins
# - Tuples as lightweight records and return values
#
# You will practice tuple assignment and the packing and unpacking operators used with variable-length argument lists.

# %% [markdown]
# <h2>Video</h2>
#
# This overview introduces Python lists, tuples, and sets, including the differences between mutable and immutable sequence types.
#
# ```{raw} html
# <iframe width="100%" height="400" src="https://www.youtube-nocookie.com/embed/W8KRzm-HUcc" title="Python Tutorial for Beginners 4: Lists, Tuples, and Sets" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen referrerpolicy="strict-origin-when-cross-origin"></iframe>
# ```
#
# > *[Python Tutorial for Beginners 4: Lists, Tuples, and Sets](https://youtube.com/watch?v=W8KRzm-HUcc) by Corey Schafer*

# %% [markdown]
# <h2>Learning Goals</h2>
#
# By the end of this chapter, you will be able to:
#
# 1. Create tuples using literals, packing, and the `tuple()` constructor
# 2. Unpack tuples, including starred unpacking, in assignments and loops
# 3. Use `zip()`, `enumerate()`, `divmod()`, and other tuple-aware built-ins
# 4. Choose between tuples and lists based on mutability needs
# 5. Return multiple values from a function using tuples

# %% [markdown]
# <h2><a href="overview.html" target="_blank"><strong>Chapter Overview Slides</strong></a></h2>

# %% [markdown]
# <h2>Chapter Flow</h2>
#
# ```{tableofcontents}
# ```
