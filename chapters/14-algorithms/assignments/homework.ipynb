# %% [markdown]
# # Homework
#
# - Use these questions after class to check your understanding of the chapter concepts and coding skills.
# - Sign in from the account menu before you start working on the homework.
# - Complete all true/false and coding questions before you submit the homework.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.
#
# <style>
# .tf-options { display: flex; gap: 1.25rem; flex-wrap: wrap; margin: 0.4rem 0 0.15rem; font-size: inherit !important; }
# .tf-options label { display: inline-flex; align-items: center; gap: 0.35rem; cursor: pointer; font-size: inherit !important; font-weight: 400 !important; line-height: 1.4; }
# .tf-options input { margin: 0; }
# .cell:has(.tf-options) { margin-bottom: 0.1rem; }
# .cell:has(.tf-options) + .cell { margin-top: 0; margin-bottom: 1.65rem; }
# .cell:has(.tf-options) + .cell details { margin-top: 0; }
# </style>
#
# <div data-assignment-answers="ch14-homework"></div>

# %% [markdown]
# ::::{div} assignment-question-card
#
# **1. Algorithm Design**
#
# Before coding, a team can compare two possible step-by-step procedures for the same task and choose the clearer or faster algorithm.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 1 answer">
#   <label><input type="radio" name="ch14-hw-q1" value="true"> True</label>
#   <label><input type="radio" name="ch14-hw-q1" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# This workplace case matches the chapter concept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **2. Big O**
#
# Big O notation describes how work grows as input size grows, not the exact number of seconds on one laptop.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 2 answer">
#   <label><input type="radio" name="ch14-hw-q2" value="true"> True</label>
#   <label><input type="radio" name="ch14-hw-q2" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# This workplace case matches the chapter concept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **3. Linear Search**
#
# Linear search requires sorted input before it can check each value one at a time.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 3 answer">
#   <label><input type="radio" name="ch14-hw-q3" value="true"> True</label>
#   <label><input type="radio" name="ch14-hw-q3" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# The case reverses or overstates the chapter concept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **4. Binary Search**
#
# Binary search relies on sorted data so each comparison can discard about half of the remaining search space.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 4 answer">
#   <label><input type="radio" name="ch14-hw-q4" value="true"> True</label>
#   <label><input type="radio" name="ch14-hw-q4" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# This workplace case matches the chapter concept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **5. Sorting**
#
# A sorting algorithm can be evaluated only by whether it changes the original list in place.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 5 answer">
#   <label><input type="radio" name="ch14-hw-q5" value="true"> True</label>
#   <label><input type="radio" name="ch14-hw-q5" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# The case reverses or overstates the chapter concept.

# %%
### 6. Run linear search
# Find the target index with a loop. Print exactly this line:
# # Index: 3
values = [14, 22, 31, 45, 59]
target = 45

### Your code starts here.



### Your code ends here.

# %%
### Solution
values = [14, 22, 31, 45, 59]
target = 45
index = -1

for position, value in enumerate(values):
    if value == target:
        index = position
        break

print("Index:", index)
# Out:
# Index: 3

# %%
### 7. Run binary search
# Use a while loop for binary search. Print exactly this line:
# # Found at: 4
values = [3, 8, 12, 19, 25, 31]
target = 25

### Your code starts here.



### Your code ends here.

# %%
### Solution
values = [3, 8, 12, 19, 25, 31]
target = 25
left = 0
right = len(values) - 1
found = -1

while left <= right:
    mid = (left + right) // 2
    if values[mid] == target:
        found = mid
        break
    if values[mid] < target:
        left = mid + 1
    else:
        right = mid - 1

print("Found at:", found)
# Out:
# Found at: 4

# %%
### 8. Use insertion-sort logic
# Insert 74 into the sorted list. Print exactly this line:
# # Scores: [61, 68, 74, 80, 92]
scores = [61, 68, 80, 92]
new_score = 74

### Your code starts here.



### Your code ends here.

# %%
### Solution
scores = [61, 68, 80, 92]
new_score = 74
position = 0

while position < len(scores) and scores[position] < new_score:
    position += 1

scores.insert(position, new_score)
print("Scores:", scores)
# Out:
# Scores: [61, 68, 74, 80, 92]

# %%
### 9. Compare sorted copy to original
# Use `sorted` without mutating the original. Print exactly these two lines:
# # Sorted: [1, 3, 5, 9]
# # Original: [5, 1, 9, 3]
values = [5, 1, 9, 3]

### Your code starts here.



### Your code ends here.

# %%
### Solution
values = [5, 1, 9, 3]
sorted_values = sorted(values)
print("Sorted:", sorted_values)
print("Original:", values)
# Out:
# Sorted: [1, 3, 5, 9]
# Original: [5, 1, 9, 3]

# %%
### 10. Count comparisons
# Count comparisons made by linear search for a missing target. Print exactly this line:
# # Comparisons: 5
values = [4, 8, 15, 16, 23]
target = 42

### Your code starts here.



### Your code ends here.

# %%
### Solution
values = [4, 8, 15, 16, 23]
target = 42
comparisons = 0

for value in values:
    comparisons += 1
    if value == target:
        break

print("Comparisons:", comparisons)
# Out:
# Comparisons: 5

# %% [markdown]
# <style>
# .ch14-homework-submit { max-width: 900px; margin-top: 1rem; }
# .ch14-homework-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch14-homework-feedback-list[hidden] { display: none; }
# .ch14-homework-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch14-homework-feedback-row strong { margin-right: 0.35rem; }
# .ch14-homework-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch14-homework-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch14-homework-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch14-homework-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch14-homework-actions button.secondary { background: white; color: #176de8; }
# .ch14-homework-actions.is-locked { opacity: 0.55; }
# .ch14-homework-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch14-homework-result { font-weight: 700; }
# </style>
#
# <div class='ch14-homework-submit' id='ch14-homework-submit-panel'>
#   <div class='ch14-homework-feedback-list' aria-live='polite' hidden>
#     <div class='ch14-homework-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch14-homework-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch14-homework-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch14-homework-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch14-homework-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#     <div class='ch14-homework-feedback-row' data-question='q6'><strong>Question 6</strong><span></span></div>
#     <div class='ch14-homework-feedback-row' data-question='q7'><strong>Question 7</strong><span></span></div>
#     <div class='ch14-homework-feedback-row' data-question='q8'><strong>Question 8</strong><span></span></div>
#     <div class='ch14-homework-feedback-row' data-question='q9'><strong>Question 9</strong><span></span></div>
#     <div class='ch14-homework-feedback-row' data-question='q10'><strong>Question 10</strong><span></span></div>
#   </div>
#   <div class='ch14-homework-actions'>
#     <button type='button' id='ch14-homework-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch14-homework-reset'>Clear Results</button>
#     <span class='ch14-homework-result' id='ch14-homework-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var homeworkId = 'ch14-homework';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var codeMirror = cell.querySelector('.CodeMirror');
#     if (codeMirror && codeMirror.CodeMirror && typeof codeMirror.CodeMirror.getValue === 'function') {
#       return codeMirror.CodeMirror.getValue();
#     }
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent) {
#       return Array.from(cmContent.querySelectorAll('.cm-line')).map(function (line) { return line.textContent; }).join('\n');
#     }
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.from(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 6)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function collectAnswers() {
#     var answers = {};
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var selected = document.querySelector('input[name=ch02-hw-' + question + ']:checked');
#       answers[question] = selected ? selected.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(panel, feedback) {
#     var list = panel.querySelector('.ch14-homework-feedback-list');
#     if (list) list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10'].forEach(function (question) {
#       var row = panel.querySelector('[data-question=' + question + ']');
#       var message = row ? row.querySelector('span') : null;
#       var item = feedback ? feedback[question] : null;
#       if (!row || !message || !item) return;
#       row.classList.remove('correct', 'incorrect');
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(panel) {
#     var list = panel.querySelector('.ch14-homework-feedback-list');
#     if (list) list.hidden = true;
#     panel.querySelectorAll('.ch14-homework-feedback-row').forEach(function (row) {
#       row.classList.remove('correct', 'incorrect');
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/homework-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var saved = text ? JSON.parse(text) : null;
#         if (!response.ok || !saved || !saved.ok) throw new Error(saved && (saved.message || saved.error) ? (saved.message || saved.error) : 'Submission API is unavailable.');
#         return saved;
#       });
#     });
#   }
#
#   function initHomeworkSubmit() {
#     var panel = document.getElementById('ch14-homework-submit-panel');
#     if (!panel || panel.dataset.ready === 'true') return;
#     panel.dataset.ready = 'true';
#
#     var identity = getParams();
#     var result = document.getElementById('ch14-homework-result');
#     var submit = document.getElementById('ch14-homework-submit');
#     var actions = panel.querySelector('.ch14-homework-actions');
#     var reset = document.getElementById('ch14-homework-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(panel);
#       result.textContent = 'Submitting homework.';
#       submit.disabled = true;
#       saveAttempt({
#         homework_id: homeworkId,
#         answers: collectAnswers(),
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           if (payload.feedback) applyFeedback(panel, payload.feedback);
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(panel);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initHomeworkSubmit);
#   } else {
#     initHomeworkSubmit();
#   }
# })();
# </script>
