# %% [markdown]
# # Lab
#
# - Use this lab to practice the chapter's coding skills in runnable Python code.
# - Sign in from the account menu before you start working on the lab.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.
#
# <div data-assignment-answers="ch14-lab"></div>

# %%
### Question 1: Find the Minimum and Maximum in One Pass
# Write find_min_max(nums) that scans the list once (a single for
# loop) and returns a tuple (minimum, maximum) WITHOUT using the
# built-in min() or max() functions.
# Call it on nums, unpack the result into low and high, and print
# exactly these two lines:
# Minimum: 1
# Maximum: 9
nums = [5, 2, 8, 1, 9, 3]
### Your code starts here.



### Your code ends here.

# %%
### Solution
nums = [5, 2, 8, 1, 9, 3]

def find_min_max(nums):
    current_min = nums[0]
    current_max = nums[0]
    for n in nums[1:]:
        if n < current_min:
            current_min = n
        if n > current_max:
            current_max = n
    return current_min, current_max

low, high = find_min_max(nums)
print("Minimum:", low)
print("Maximum:", high)
# Out:
# Minimum: 1
# Maximum: 9

# %%
### Question 2: Binary Search on a New Sorted List
# Write binary_search(sorted_nums, target) that returns the index
# of target in sorted_nums, or -1 if it is not present, using the
# standard low/high/mid halving algorithm (O(log n)).
# Call binary_search(sorted_nums, 47), then binary_search(sorted_nums, 10),
# and print each result on its own line. Print exactly:
# 5
# -1
sorted_nums = [3, 8, 15, 22, 34, 47, 59, 68, 71, 90]
### Your code starts here.



### Your code ends here.

# %%
### Solution
sorted_nums = [3, 8, 15, 22, 34, 47, 59, 68, 71, 90]

def binary_search(sorted_nums, target):
    low, high = 0, len(sorted_nums) - 1
    while low <= high:
        mid = (low + high) // 2
        if sorted_nums[mid] == target:
            return mid
        elif sorted_nums[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return -1

print(binary_search(sorted_nums, 47))
print(binary_search(sorted_nums, 10))
# Out:
# 5
# -1

# %%
### Question 3: Insert-and-Report with bisect
# scores is already sorted. Use bisect.bisect_left(scores, new_score)
# to find the index where new_score would be inserted to keep the
# list sorted, and store it in position.
# Then use bisect.insort(scores, new_score) to actually insert it
# in place.
# Print exactly these two lines:
# Insert position: 3
# Updated scores: [55, 62, 74, 79, 81, 88, 95]
import bisect

scores = [55, 62, 74, 81, 88, 95]
new_score = 79
### Your code starts here.



### Your code ends here.

# %%
### Solution
import bisect

scores = [55, 62, 74, 81, 88, 95]
new_score = 79

position = bisect.bisect_left(scores, new_score)
bisect.insort(scores, new_score)

print("Insert position:", position)
print("Updated scores:", scores)
# Out:
# Insert position: 3
# Updated scores: [55, 62, 74, 79, 81, 88, 95]

# %%
### Question 4: Implement Insertion Sort
# Write insertion_sort(data) that returns a NEW sorted list using
# insertion sort logic: work on a copy (items = data[:]) so the
# original data list is never mutated.
# For each index i from 1 to the end, slide items[i] left past any
# larger items in the sorted portion until it reaches its place.
# Call insertion_sort(data), then print the result and print data
# again to show it is unchanged. Print exactly:
# Sorted: [1, 3, 6, 8, 9]
# Original unchanged: [8, 3, 9, 1, 6]
data = [8, 3, 9, 1, 6]
### Your code starts here.



### Your code ends here.

# %%
### Solution
data = [8, 3, 9, 1, 6]

def insertion_sort(data):
    items = data[:]
    for i in range(1, len(items)):
        current = items[i]
        j = i - 1
        while j >= 0 and items[j] > current:
            items[j + 1] = items[j]
            j -= 1
        items[j + 1] = current
    return items

sorted_data = insertion_sort(data)
print("Sorted:", sorted_data)
print("Original unchanged:", data)
# Out:
# Sorted: [1, 3, 6, 8, 9]
# Original unchanged: [8, 3, 9, 1, 6]

# %%
### Question 5: Count Comparisons in Linear Search
# Write linear_search_count(data, target) that scans data left to
# right, counting every comparison made (increment comparisons once
# per element checked). Return a tuple (index, comparisons); index
# is -1 if target is never found, and comparisons still reflects the
# full scan in that case.
# Call it for target 23, then for target 100, printing each result
# with a label. Print exactly these two lines:
# Target 23: (3, 4)
# Target 100: (-1, 7)
data = [12, 45, 7, 23, 56, 89, 34]
### Your code starts here.



### Your code ends here.

# %%
### Solution
data = [12, 45, 7, 23, 56, 89, 34]

def linear_search_count(data, target):
    comparisons = 0
    for i, value in enumerate(data):
        comparisons += 1
        if value == target:
            return i, comparisons
    return -1, comparisons

print("Target 23:", linear_search_count(data, 23))
print("Target 100:", linear_search_count(data, 100))
# Out:
# Target 23: (3, 4)
# Target 100: (-1, 7)

# %% [markdown]
# <style>
# .ch14-lab-grader { max-width: 900px; margin-top: 1rem; }
# .ch14-lab-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch14-lab-feedback-list[hidden] { display: none; }
# .ch14-lab-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch14-lab-feedback-row strong { margin-right: 0.35rem; }
# .ch14-lab-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch14-lab-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch14-lab-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch14-lab-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch14-lab-actions button.secondary { background: white; color: #176de8; }
# .ch14-lab-actions.is-locked { opacity: 0.55; }
# .ch14-lab-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch14-lab-result { font-weight: 700; }
# </style>
#
# <div class='ch14-lab-grader' id='ch14-lab-grader'>
#   <div class='ch14-lab-feedback-list' aria-live='polite' hidden>
#     <div class='ch14-lab-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch14-lab-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch14-lab-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch14-lab-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch14-lab-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#   </div>
#   <div class='ch14-lab-actions'>
#     <button type='button' id='ch14-lab-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch14-lab-reset'>Clear Results</button>
#     <span class='ch14-lab-result' id='ch14-lab-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var labId = 'ch14-lab';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var codeMirror = cell.querySelector('.CodeMirror');
#     if (codeMirror && codeMirror.CodeMirror && typeof codeMirror.CodeMirror.getValue === 'function') {
#       return codeMirror.CodeMirror.getValue();
#     }
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent) {
#       return Array.from(cmContent.querySelectorAll('.cm-line')).map(function (line) { return line.textContent; }).join('\n');
#     }
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.from(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 1)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function applyFeedback(grader, feedback) {
#     var list = grader.querySelector('.ch14-lab-feedback-list');
#     if (list) list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var row = grader.querySelector('[data-question=' + question + ']');
#       var message = row ? row.querySelector('span') : null;
#       var item = feedback ? feedback[question] : null;
#       if (!row || !message || !item) return;
#       row.classList.remove('correct', 'incorrect');
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(grader) {
#     var list = grader.querySelector('.ch14-lab-feedback-list');
#     if (list) list.hidden = true;
#     grader.querySelectorAll('.ch14-lab-feedback-row').forEach(function (row) {
#       row.classList.remove('correct', 'incorrect');
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/lab-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var saved = text ? JSON.parse(text) : null;
#         if (!response.ok || !saved || !saved.ok) throw new Error(saved && (saved.message || saved.error) ? (saved.message || saved.error) : 'Submission API is unavailable.');
#         return saved;
#       });
#     });
#   }
#
#   function initLabGrader() {
#     var grader = document.getElementById('ch14-lab-grader');
#     if (!grader || grader.dataset.ready === 'true') return;
#     grader.dataset.ready = 'true';
#
#     var identity = getParams();
#     var result = document.getElementById('ch14-lab-result');
#     var submit = document.getElementById('ch14-lab-submit');
#     var actions = grader.querySelector('.ch14-lab-actions');
#     var reset = document.getElementById('ch14-lab-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = 'Submitting code.';
#       submit.disabled = true;
#       saveAttempt({
#         lab_id: labId,
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           if (payload.feedback) applyFeedback(grader, payload.feedback);
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initLabGrader);
#   } else {
#     initLabGrader();
#   }
# })();
# </script>
