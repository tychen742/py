# %% [markdown]
# # Homework
#
# - Use these questions after class to check your understanding of the chapter concepts and coding skills.
# - Sign in from the account menu before you start working on the homework.
# - Complete all true/false and coding questions before you submit the homework.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.
#
# <style>
# .tf-options { display: flex; gap: 1.25rem; flex-wrap: wrap; margin: 0.4rem 0 0.15rem; }
# .tf-options label { display: inline-flex; align-items: center; gap: 0.35rem; cursor: pointer; }
# .tf-options input { margin: 0; }
# .cell:has(.tf-options) { margin-bottom: 0.1rem; }
# .cell:has(.tf-options) + .cell { margin-top: 0; margin-bottom: 1.65rem; }
# .cell:has(.tf-options) + .cell details { margin-top: 0; }
# </style>
#
# <div data-assignment-answers="ch11-homework"></div>

# %% [markdown]
# ::::{div} assignment-question-card
#
# **1. Iterator Protocol**
#
# An object used with repeated `next()` calls is acting through the iterator protocol.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 1 answer">
#   <label><input type="radio" name="ch11-hw-q1" value="true"> True</label>
#   <label><input type="radio" name="ch11-hw-q1" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# This workplace case matches the chapter concept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **2. Laziness**
#
# A generator can produce values one at a time instead of building a full list immediately.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 2 answer">
#   <label><input type="radio" name="ch11-hw-q2" value="true"> True</label>
#   <label><input type="radio" name="ch11-hw-q2" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# This workplace case matches the chapter concept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **3. StopIteration**
#
# A custom iterator should return the string `"done"` forever when it runs out of values.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 3 answer">
#   <label><input type="radio" name="ch11-hw-q3" value="true"> True</label>
#   <label><input type="radio" name="ch11-hw-q3" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# The case reverses or overstates the chapter concept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **4. Generator Expressions**
#
# A generator expression is useful when a pipeline needs values lazily and does not need to store every intermediate result.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 4 answer">
#   <label><input type="radio" name="ch11-hw-q4" value="true"> True</label>
#   <label><input type="radio" name="ch11-hw-q4" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# This workplace case matches the chapter concept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **5. Yield**
#
# A function that contains `yield` behaves exactly like a normal function that immediately returns a list.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 5 answer">
#   <label><input type="radio" name="ch11-hw-q5" value="true"> True</label>
#   <label><input type="radio" name="ch11-hw-q5" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# The case reverses or overstates the chapter concept.

# %%
### 6. Use `iter` and `next`
# Create an iterator and read two values. Print exactly these two lines:
# # First: 10
# # Second: 20
values = [10, 20, 30]

### Your code starts here.



### Your code ends here.

# %%
### Solution
values = [10, 20, 30]
iterator = iter(values)
print("First:", next(iterator))
print("Second:", next(iterator))
# Out:
# First: 10
# Second: 20

# %%
### 7. Write a generator function
# Define `countdown(n)`. Print exactly this line:
# # Countdown: [3, 2, 1]
### Your code starts here.



### Your code ends here.

# %%
### Solution
def countdown(n):
    while n > 0:
        yield n
        n -= 1

print("Countdown:", list(countdown(3)))
# Out:
# Countdown: [3, 2, 1]

# %%
### 8. Use a generator expression
# Sum only positive values using a generator expression. Print exactly this line:
# # Positive total: 14
values = [10, -3, 4, -1]

### Your code starts here.



### Your code ends here.

# %%
### Solution
values = [10, -3, 4, -1]
positive_total = sum(value for value in values if value > 0)
print("Positive total:", positive_total)
# Out:
# Positive total: 14

# %%
### 9. Handle iterator exhaustion
# Catch `StopIteration`. Print exactly these three lines:
# # Ana
# # Bob
# # No more names
names = iter(["Ana", "Bob"])

### Your code starts here.



### Your code ends here.

# %%
### Solution
names = iter(["Ana", "Bob"])

try:
    print(next(names))
    print(next(names))
    print(next(names))
except StopIteration:
    print("No more names")
# Out:
# Ana
# Bob
# No more names

# %%
### 10. Chain generated values
# Define `repeat_each(values, times)` and print exactly this line:
# # Repeated: ['A', 'A', 'B', 'B']
### Your code starts here.



### Your code ends here.

# %%
### Solution
def repeat_each(values, times):
    for value in values:
        for _ in range(times):
            yield value

print("Repeated:", list(repeat_each(["A", "B"], 2)))
# Out:
# Repeated: ['A', 'A', 'B', 'B']

# %% [markdown]
# <style>
# .ch11-homework-submit { max-width: 900px; margin-top: 1rem; }
# .ch11-homework-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch11-homework-feedback-list[hidden] { display: none; }
# .ch11-homework-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch11-homework-feedback-row strong { margin-right: 0.35rem; }
# .ch11-homework-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch11-homework-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch11-homework-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch11-homework-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch11-homework-actions button.secondary { background: white; color: #176de8; }
# .ch11-homework-actions.is-locked { opacity: 0.55; }
# .ch11-homework-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch11-homework-result { font-weight: 700; }
# </style>
#
# <div class='ch11-homework-submit' id='ch11-homework-submit-panel'>
#   <div class='ch11-homework-feedback-list' aria-live='polite' hidden>
#     <div class='ch11-homework-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch11-homework-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch11-homework-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch11-homework-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch11-homework-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#     <div class='ch11-homework-feedback-row' data-question='q6'><strong>Question 6</strong><span></span></div>
#     <div class='ch11-homework-feedback-row' data-question='q7'><strong>Question 7</strong><span></span></div>
#     <div class='ch11-homework-feedback-row' data-question='q8'><strong>Question 8</strong><span></span></div>
#     <div class='ch11-homework-feedback-row' data-question='q9'><strong>Question 9</strong><span></span></div>
#     <div class='ch11-homework-feedback-row' data-question='q10'><strong>Question 10</strong><span></span></div>
#   </div>
#   <div class='ch11-homework-actions'>
#     <button type='button' id='ch11-homework-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch11-homework-reset'>Clear Results</button>
#     <span class='ch11-homework-result' id='ch11-homework-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var homeworkId = 'ch11-homework';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var codeMirror = cell.querySelector('.CodeMirror');
#     if (codeMirror && codeMirror.CodeMirror && typeof codeMirror.CodeMirror.getValue === 'function') {
#       return codeMirror.CodeMirror.getValue();
#     }
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent) {
#       return Array.from(cmContent.querySelectorAll('.cm-line')).map(function (line) { return line.textContent; }).join('\n');
#     }
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.from(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 6)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function collectAnswers() {
#     var answers = {};
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var selected = document.querySelector('input[name=ch02-hw-' + question + ']:checked');
#       answers[question] = selected ? selected.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(panel, feedback) {
#     var list = panel.querySelector('.ch11-homework-feedback-list');
#     if (list) list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10'].forEach(function (question) {
#       var row = panel.querySelector('[data-question=' + question + ']');
#       var message = row ? row.querySelector('span') : null;
#       var item = feedback ? feedback[question] : null;
#       if (!row || !message || !item) return;
#       row.classList.remove('correct', 'incorrect');
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(panel) {
#     var list = panel.querySelector('.ch11-homework-feedback-list');
#     if (list) list.hidden = true;
#     panel.querySelectorAll('.ch11-homework-feedback-row').forEach(function (row) {
#       row.classList.remove('correct', 'incorrect');
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/homework-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var saved = text ? JSON.parse(text) : null;
#         if (!response.ok || !saved || !saved.ok) throw new Error(saved && (saved.message || saved.error) ? (saved.message || saved.error) : 'Submission API is unavailable.');
#         return saved;
#       });
#     });
#   }
#
#   function initHomeworkSubmit() {
#     var panel = document.getElementById('ch11-homework-submit-panel');
#     if (!panel || panel.dataset.ready === 'true') return;
#     panel.dataset.ready = 'true';
#
#     var identity = getParams();
#     var result = document.getElementById('ch11-homework-result');
#     var submit = document.getElementById('ch11-homework-submit');
#     var actions = panel.querySelector('.ch11-homework-actions');
#     var reset = document.getElementById('ch11-homework-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(panel);
#       result.textContent = 'Submitting homework.';
#       submit.disabled = true;
#       saveAttempt({
#         homework_id: homeworkId,
#         answers: collectAnswers(),
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           if (payload.feedback) applyFeedback(panel, payload.feedback);
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(panel);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initHomeworkSubmit);
#   } else {
#     initHomeworkSubmit();
#   }
# })();
# </script>
