# %% [markdown]
# # Ch09 Preview Questions
#
# Answer these questions before class to prime yourself for the Object-Oriented Programming chapter.

# %% [markdown]
# ## 1. Key Ideas
#
# What are two concepts you expect to use in this chapter?

# %% [markdown]
# ## 2. Prior Knowledge
#
# What related Python idea have you seen before?

# %% [markdown]
# ## 3. Application
#
# Name one programming or data task where this chapter topic could be useful.
