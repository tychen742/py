# %% [markdown]
# # Lab
#
# **Due:** See Canvas for the current due date, 11:59 PM CT.
# **Answers unlock:** after the lab due date.
#
# This lab gives you technical practice with Chapter 1: running a first Python program, using expressions and statements, formatting output, converting input strings, and checking number systems and character encodings.
#
# Complete the code cells first. Then submit the current code from the interactive cells at the bottom.
#
# **Multiple submissions are allowed. The highest score is kept.**
#
# <div data-assignment-answers="ch01-lab"></div>

# %%
### Question 1: First runnable program
# Create a variable named course_name and store "ThinkPy" in it.
# Create a variable named chapter_number and store 1 in it.
# Print exactly two lines:
# ThinkPy Chapter 1
# Python is running.
### Your code starts here.



### Your code ends here.

# %%
### Solution
course_name = "ThinkPy"
chapter_number = 1

print(f"{course_name} Chapter {chapter_number}")
print("Python is running.")

# %%
### Question 2: Expressions and assignment statements
# The variables below describe a short reading plan.
# Write assignment statements that calculate total_pages and average_pages_per_day.
# Print both values. Use round(average_pages_per_day, 2) for the average.
hours = 6
pages_per_hour = 14
review_pages = 9
days = 5
### Your code starts here.



### Your code ends here.

# %%
### Solution
hours = 6
pages_per_hour = 14
review_pages = 9
days = 5

total_pages = hours * pages_per_hour + review_pages
average_pages_per_day = total_pages / days

print("Total pages:", total_pages)
print("Average per day:", round(average_pages_per_day, 2))

# %%
### Question 3: Formatted output
# Use the variables below to print exactly these two lines:
# sales: 128 rows x 5 columns
# sales|128|5
# Use an f-string for the first line.
# Use print() with sep="|" for the second line.
dataset_name = "sales"
row_count = 128
column_count = 5
### Your code starts here.



### Your code ends here.

# %%
### Solution
dataset_name = "sales"
row_count = 128
column_count = 5

print(f"{dataset_name}: {row_count} rows x {column_count} columns")
print(dataset_name, row_count, column_count, sep="|")

# %%
### Question 4: Convert text input to numbers
# input() returns text, so numeric input usually needs conversion.
# The variable below simulates text a user typed into input().
# Convert minutes_text to an integer named total_minutes.
# Calculate full hours in a variable named hours_part.
# Calculate leftover minutes in a variable named minutes_part.
# Print hours_part and minutes_part.
minutes_text = "135"
### Your code starts here.



### Your code ends here.

# %%
### Solution
minutes_text = "135"

total_minutes = int(minutes_text)
hours_part = total_minutes // 60
minutes_part = total_minutes % 60

print("Hours:", hours_part)
print("Minutes:", minutes_part)

# %%
### Question 5: Number systems and character encoding
# A simple inventory system uses product code "C" and item number 64.
# Save the decimal code for "C" in c_decimal using ord().
# Save the binary representation of c_decimal in c_binary using bin().
# Save the hexadecimal representation of item_number in item_hex using hex().
# Print c_decimal, c_binary, and item_hex.
item_number = 64
### Your code starts here.



### Your code ends here.

# %%
### Solution
item_number = 64

c_decimal = ord("C")
c_binary = bin(c_decimal)
item_hex = hex(item_number)

print("C decimal:", c_decimal)
print("C binary:", c_binary)
print("Item hex:", item_hex)

# %% [markdown]
# ## Submit Lab Code
#
# <style>
# .ch01-lab-grader { max-width: 900px; margin-top: 1rem; border: 1px solid #d8dee4; border-radius: 6px; padding: 1rem; background: #fff; }
# .ch01-lab-grader p { margin-top: 0; }
# .ch01-lab-feedback-list { display: grid; gap: 0.45rem; margin: 0.75rem 0 1rem; }
# .ch01-lab-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch01-lab-feedback-row strong { margin-right: 0.35rem; }
# .ch01-lab-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch01-lab-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch01-lab-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch01-lab-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch01-lab-actions button.secondary { background: white; color: #176de8; }
# .ch01-lab-actions.is-locked { opacity: 0.55; }
# .ch01-lab-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch01-lab-result { font-weight: 700; }
# </style>
#
# <div class='ch01-lab-grader' id='ch01-lab-grader'>
#   <p>Submit the current code from the five interactive exercise cells.</p>
#   <div class='ch01-lab-feedback-list' aria-live='polite'>
#     <div class='ch01-lab-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch01-lab-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch01-lab-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch01-lab-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch01-lab-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#   </div>
#   <div class='ch01-lab-actions'>
#     <button type='button' id='ch01-lab-submit'>Submit Code</button>
#     <button type='button' class='secondary' id='ch01-lab-reset'>Clear Results</button>
#     <span class='ch01-lab-result' id='ch01-lab-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var labId = 'ch01-lab';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var codeMirror = cell.querySelector('.CodeMirror');
#     if (codeMirror && codeMirror.CodeMirror && typeof codeMirror.CodeMirror.getValue === 'function') {
#       return codeMirror.CodeMirror.getValue();
#     }
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent) {
#       return Array.from(cmContent.querySelectorAll('.cm-line')).map(function (line) { return line.textContent; }).join('\n');
#     }
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.from(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 1)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function applyFeedback(grader, feedback) {
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var row = grader.querySelector('[data-question=' + question + ']');
#       var message = row ? row.querySelector('span') : null;
#       var item = feedback ? feedback[question] : null;
#       if (!row || !message || !item) return;
#       row.classList.remove('correct', 'incorrect');
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(grader) {
#     grader.querySelectorAll('.ch01-lab-feedback-row').forEach(function (row) {
#       row.classList.remove('correct', 'incorrect');
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/lab-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var saved = text ? JSON.parse(text) : null;
#         if (!response.ok || !saved || !saved.ok) throw new Error(saved && (saved.message || saved.error) ? (saved.message || saved.error) : 'Submission API is unavailable.');
#         return saved;
#       });
#     });
#   }
#
#   function initLabGrader() {
#     var grader = document.getElementById('ch01-lab-grader');
#     if (!grader || grader.dataset.ready === 'true') return;
#     grader.dataset.ready = 'true';
#
#     var identity = getParams();
#     var result = document.getElementById('ch01-lab-result');
#     var submit = document.getElementById('ch01-lab-submit');
#     var actions = grader.querySelector('.ch01-lab-actions');
#     var reset = document.getElementById('ch01-lab-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = 'Submitting code.';
#       submit.disabled = true;
#       saveAttempt({
#         lab_id: labId,
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           if (payload.feedback) applyFeedback(grader, payload.feedback);
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initLabGrader);
#   } else {
#     initLabGrader();
#   }
# })();
# </script>
