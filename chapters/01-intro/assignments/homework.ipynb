# %% [markdown]
# # Homework
#
# - Use these questions after class to check your understanding of the chapter concepts and coding skills.
# - Sign in from the account menu before you start working on the homework.
# - Complete all true/false and coding questions before you submit the homework.
# - Multiple submissions are allowed. The highest score is kept.
#
# <style>
# .tf-options { display: flex; gap: 1.25rem; flex-wrap: wrap; margin: 0.4rem 0 0.15rem; }
# .tf-options label { display: inline-flex; align-items: center; gap: 0.35rem; cursor: pointer; font-weight: 600; }
# .tf-options input { margin: 0; }
# .cell:has(.tf-options) { margin-bottom: 0.1rem; }
# .cell:has(.tf-options) + .cell { margin-top: 0; margin-bottom: 1.65rem; }
# .cell:has(.tf-options) + .cell details { margin-top: 0; }
# </style>
#
# <div data-assignment-answers="ch01-homework"></div>

# %% [markdown]
# **Question 1: Programs**
#
# **True or False:** A manager asks an analyst to write a repeatable set of Python instructions that prepares the weekly sales report. Calling that set of instructions a program is appropriate.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 1 answer">
#   <label><input type="radio" name="ch01-hw-q1" value="true"> True</label>
#   <label><input type="radio" name="ch01-hw-q1" value="false"> False</label>
# </div>

# %%
### Solution
# True
# A repeatable set of Python instructions that prepares a report is a program.

# %% [markdown]
# **Question 2: Algorithms**
#
# **True or False:** Before assigning a dashboard task, a team lead sketches the step-by-step logic for cleaning, grouping, and summarizing customer records without choosing Python syntax yet. That sketch can still be an algorithm.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 2 answer">
#   <label><input type="radio" name="ch01-hw-q2" value="true"> True</label>
#   <label><input type="radio" name="ch01-hw-q2" value="false"> False</label>
# </div>

# %%
### Solution
# True
# An algorithm can describe the step-by-step logic before the team chooses exact Python syntax.

# %% [markdown]
# **Question 3: Syntax**
#
# **True or False:** A supervisor reviews a script that has the right business logic but missing parentheses and mismatched quotes. Because the business logic is correct, Python syntax rules do not matter for whether the script can run.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 3 answer">
#   <label><input type="radio" name="ch01-hw-q3" value="true"> True</label>
#   <label><input type="radio" name="ch01-hw-q3" value="false"> False</label>
# </div>

# %%
### Solution
# False
# Correct business logic is not enough; syntax errors can stop Python before the script runs.

# %% [markdown]
# **Question 4: Comments**
#
# **True or False:** A project manager asks the team to add notes explaining why a pricing rule exists. If those notes are written as Python lines starting with `#`, they normally document the script without changing what runs.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 4 answer">
#   <label><input type="radio" name="ch01-hw-q4" value="true"> True</label>
#   <label><input type="radio" name="ch01-hw-q4" value="false"> False</label>
# </div>

# %%
### Solution
# True
# Lines that start with # are comments, so they document the script without changing execution.

# %% [markdown]
# **Question 5: Input Values**
#
# **True or False:** An operations form asks for the number of units to reorder. If a Python script reads that value with `input()`, Python automatically treats it as a number whenever the next line multiplies it by a price.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 5 answer">
#   <label><input type="radio" name="ch01-hw-q5" value="true"> True</label>
#   <label><input type="radio" name="ch01-hw-q5" value="false"> False</label>
# </div>

# %%
### Solution
# False
# input() returns text, so numeric form values usually need conversion before arithmetic.

# %%
### Question 6: Fix a Syntax Error
# The code below contains two syntax problems:
# print("ThinkPy homework"
# print("Chapter 1 is about first programs")
# Write the corrected version so it prints exactly:
# ThinkPy homework
# Chapter 1 is about first programs
### Your code starts here.



### Your code ends here.

# %%
### Solution
print("ThinkPy homework")
print("Chapter 1 is about first programs")

# %%
### Question 7: Update a Running Count
# The lab asked you to calculate values once. Here, update a variable as a count changes.
# Start with open_tickets. Add new_tickets, subtract closed_tickets, and print exactly:
# Open tickets: 9

open_tickets = 12
new_tickets = 5
closed_tickets = 8

### Your code starts here.



### Your code ends here.

# %%
### Solution
open_tickets = 12
new_tickets = 5
closed_tickets = 8

open_tickets = open_tickets + new_tickets - closed_tickets

print("Open tickets:", open_tickets)

# %%
### Question 8: Inspect Converted Input
# The lab converted text input to a number. Here, confirm the type changes after conversion.
# Convert quantity_text to an integer named quantity.
# Print exactly:
# Before: <class 'str'>
# After: <class 'int'>

quantity_text = "42"

### Your code starts here.



### Your code ends here.

# %%
### Solution
quantity_text = "42"
quantity = int(quantity_text)

print("Before:", type(quantity_text))
print("After:", type(quantity))

# %%
### Question 9: Write a Stakeholder Message
# The lab practiced formatted output. Here, write a short message for a business reader.
# Use an f-string and the variables below to print exactly:
# North region needs 6 follow-up calls.

region = "North"
follow_up_calls = 6

### Your code starts here.



### Your code ends here.

# %%
### Solution
region = "North"
follow_up_calls = 6

print(f"{region} region needs {follow_up_calls} follow-up calls.")

# %%
### Question 10: Build an Audit Tag
# The lab printed separate number-system and character-code values.
# Here, combine an initial, its numeric code, and a hex item number into one tag.
# Use ord(), str(), and hex() to print exactly:
# Audit tag: A-65-0xff

initial = "A"
item_number = 255

### Your code starts here.



### Your code ends here.

# %%
### Solution
initial = "A"
item_number = 255

initial_code = ord(initial)
item_hex = hex(item_number)
tag = initial + "-" + str(initial_code) + "-" + item_hex

print("Audit tag:", tag)

# %% [markdown]
# <style>
# .ch01-homework-submit { max-width: 900px; margin-top: 1rem; }
# .ch01-homework-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch01-homework-feedback-list[hidden] { display: none; }
# .ch01-homework-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch01-homework-feedback-row strong { margin-right: 0.35rem; }
# .ch01-homework-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch01-homework-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch01-homework-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch01-homework-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch01-homework-actions button.secondary { background: white; color: #176de8; }
# .ch01-homework-actions.is-locked { opacity: 0.55; }
# .ch01-homework-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch01-homework-result { font-weight: 700; }
# </style>
#
# <div class='ch01-homework-submit' id='ch01-homework-submit-panel'>
#   <div class='ch01-homework-feedback-list' aria-live='polite' hidden>
#     <div class='ch01-homework-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch01-homework-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch01-homework-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch01-homework-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch01-homework-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#     <div class='ch01-homework-feedback-row' data-question='q6'><strong>Question 6</strong><span></span></div>
#     <div class='ch01-homework-feedback-row' data-question='q7'><strong>Question 7</strong><span></span></div>
#     <div class='ch01-homework-feedback-row' data-question='q8'><strong>Question 8</strong><span></span></div>
#     <div class='ch01-homework-feedback-row' data-question='q9'><strong>Question 9</strong><span></span></div>
#     <div class='ch01-homework-feedback-row' data-question='q10'><strong>Question 10</strong><span></span></div>
#   </div>
#   <div class='ch01-homework-actions'>
#     <button type='button' id='ch01-homework-submit' disabled>Submit Homework</button>
#     <button type='button' class='secondary' id='ch01-homework-reset'>Clear Results</button>
#     <span class='ch01-homework-result' id='ch01-homework-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var homeworkId = 'ch01-homework';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var codeMirror = cell.querySelector('.CodeMirror');
#     if (codeMirror && codeMirror.CodeMirror && typeof codeMirror.CodeMirror.getValue === 'function') {
#       return codeMirror.CodeMirror.getValue();
#     }
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent) {
#       return Array.from(cmContent.querySelectorAll('.cm-line')).map(function (line) { return line.textContent; }).join('\n');
#     }
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.from(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 6)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function collectAnswers() {
#     var answers = {};
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var selected = document.querySelector('input[name=ch01-hw-' + question + ']:checked');
#       answers[question] = selected ? selected.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(panel, feedback) {
#     var list = panel.querySelector('.ch01-homework-feedback-list');
#     if (list) list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10'].forEach(function (question) {
#       var row = panel.querySelector('[data-question=' + question + ']');
#       var message = row ? row.querySelector('span') : null;
#       var item = feedback ? feedback[question] : null;
#       if (!row || !message || !item) return;
#       row.classList.remove('correct', 'incorrect');
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(panel) {
#     var list = panel.querySelector('.ch01-homework-feedback-list');
#     if (list) list.hidden = true;
#     panel.querySelectorAll('.ch01-homework-feedback-row').forEach(function (row) {
#       row.classList.remove('correct', 'incorrect');
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/homework-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var saved = text ? JSON.parse(text) : null;
#         if (!response.ok || !saved || !saved.ok) throw new Error(saved && (saved.message || saved.error) ? (saved.message || saved.error) : 'Submission API is unavailable.');
#         return saved;
#       });
#     });
#   }
#
#   function initHomeworkSubmit() {
#     var panel = document.getElementById('ch01-homework-submit-panel');
#     if (!panel || panel.dataset.ready === 'true') return;
#     panel.dataset.ready = 'true';
#
#     var identity = getParams();
#     var result = document.getElementById('ch01-homework-result');
#     var submit = document.getElementById('ch01-homework-submit');
#     var actions = panel.querySelector('.ch01-homework-actions');
#     var reset = document.getElementById('ch01-homework-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(panel);
#       result.textContent = 'Submitting homework.';
#       submit.disabled = true;
#       saveAttempt({
#         homework_id: homeworkId,
#         answers: collectAnswers(),
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           if (payload.feedback) applyFeedback(panel, payload.feedback);
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(panel);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initHomeworkSubmit);
#   } else {
#     initHomeworkSubmit();
#   }
# })();
# </script>
