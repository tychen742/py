# %% [markdown]
# # Homework
#
# - Use these questions after class to check your understanding of the chapter concepts and coding skills.
# - Sign in from the account menu before you start working on the homework.
# - Complete all true/false and coding questions before you submit the homework.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.
#
# <style>
# .tf-options { display: flex; gap: 1.25rem; flex-wrap: wrap; margin: 0.4rem 0 0.15rem; }
# .tf-options label { display: inline-flex; align-items: center; gap: 0.35rem; cursor: pointer; font-weight: 600; }
# .tf-options input { margin: 0; }
# .cell:has(.tf-options) { margin-bottom: 0.1rem; }
# .cell:has(.tf-options) + .cell { margin-top: 0; margin-bottom: 1.65rem; }
# .cell:has(.tf-options) + .cell details { margin-top: 0; }
# </style>
#
# <div data-assignment-answers="ch04-homework"></div>

# %% [markdown]
# ::::{div} assignment-question-card
#
# **1. Function Calls**
#
# A team that calculates the same fee in several reports should put that calculation in a function instead of copying the same expression repeatedly.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 1 answer">
#   <label><input type="radio" name="ch04-hw-q1" value="true"> True</label>
#   <label><input type="radio" name="ch04-hw-q1" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# This workplace case matches the chapter concept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **2. Return Values**
#
# A function that only prints a value automatically returns that printed text to the caller.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 2 answer">
#   <label><input type="radio" name="ch04-hw-q2" value="true"> True</label>
#   <label><input type="radio" name="ch04-hw-q2" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# The case reverses or overstates the chapter concept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **3. Scope**
#
# A variable created inside a function is normally local to that function unless it is returned or otherwise passed out.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 3 answer">
#   <label><input type="radio" name="ch04-hw-q3" value="true"> True</label>
#   <label><input type="radio" name="ch04-hw-q3" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# This workplace case matches the chapter concept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **4. Default Parameters**
#
# A reporting helper can use a default parameter when most calls use the same tax rate but a few calls need a different rate.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 4 answer">
#   <label><input type="radio" name="ch04-hw-q4" value="true"> True</label>
#   <label><input type="radio" name="ch04-hw-q4" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# This workplace case matches the chapter concept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **5. Base Cases**
#
# A recursive function can omit a base case as long as the recursive call moves toward smaller values.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 5 answer">
#   <label><input type="radio" name="ch04-hw-q5" value="true"> True</label>
#   <label><input type="radio" name="ch04-hw-q5" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# The case reverses or overstates the chapter concept.

# %%
### 6. Write a small formatter function
# Define `format_total(amount)` so the code prints exactly this line:
# # Total due: 42.75
amount = 42.75

### Your code starts here.



### Your code ends here.

# %%
### Solution
def format_total(amount):
    return f"Total due: {amount:.2f}"

amount = 42.75
print(format_total(amount))
# Out:
# Total due: 42.75

# %%
### 7. Use parameters and return values
# Define `average(values)` and print exactly this line:
# # Average score: 86.0
scores = [92, 81, 85]

### Your code starts here.



### Your code ends here.

# %%
### Solution
def average(values):
    return sum(values) / len(values)

scores = [92, 81, 85]
print("Average score:", round(average(scores), 1))
# Out:
# Average score: 86.0

# %%
### 8. Use a default argument
# Define `add_fee(price, fee=2.5)` and print exactly these two lines:
# # Standard: 12.5
# # Custom: 13.0
price = 10.0

### Your code starts here.



### Your code ends here.

# %%
### Solution
def add_fee(price, fee=2.5):
    return price + fee

price = 10.0
print("Standard:", add_fee(price))
print("Custom:", add_fee(price, fee=3.0))
# Out:
# Standard: 12.5
# Custom: 13.0

# %%
### 9. Compose small functions
# Define `subtotal` and `with_tax` helpers. Print exactly this line:
# # Total: 32.4
prices = [12, 8, 10]
tax_rate = 0.08

### Your code starts here.



### Your code ends here.

# %%
### Solution
def subtotal(values):
    return sum(values)

def with_tax(amount, tax_rate):
    return round(amount * (1 + tax_rate), 2)

prices = [12, 8, 10]
tax_rate = 0.08
print("Total:", with_tax(subtotal(prices), tax_rate))
# Out:
# Total: 32.4

# %%
### 10. Use recursion with a base case
# Define recursive `countdown_sum(n)` and print exactly this line:
# # Sum: 15
n = 5

### Your code starts here.



### Your code ends here.

# %%
### Solution
def countdown_sum(n):
    if n == 0:
        return 0
    return n + countdown_sum(n - 1)

n = 5
print("Sum:", countdown_sum(n))
# Out:
# Sum: 15

# %% [markdown]
# <style>
# .ch04-homework-submit { max-width: 900px; margin-top: 1rem; }
# .ch04-homework-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch04-homework-feedback-list[hidden] { display: none; }
# .ch04-homework-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch04-homework-feedback-row strong { margin-right: 0.35rem; }
# .ch04-homework-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch04-homework-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch04-homework-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch04-homework-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch04-homework-actions button.secondary { background: white; color: #176de8; }
# .ch04-homework-actions.is-locked { opacity: 0.55; }
# .ch04-homework-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch04-homework-result { font-weight: 700; }
# </style>
#
# <div class='ch04-homework-submit' id='ch04-homework-submit-panel'>
#   <div class='ch04-homework-feedback-list' aria-live='polite' hidden>
#     <div class='ch04-homework-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch04-homework-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch04-homework-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch04-homework-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch04-homework-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#     <div class='ch04-homework-feedback-row' data-question='q6'><strong>Question 6</strong><span></span></div>
#     <div class='ch04-homework-feedback-row' data-question='q7'><strong>Question 7</strong><span></span></div>
#     <div class='ch04-homework-feedback-row' data-question='q8'><strong>Question 8</strong><span></span></div>
#     <div class='ch04-homework-feedback-row' data-question='q9'><strong>Question 9</strong><span></span></div>
#     <div class='ch04-homework-feedback-row' data-question='q10'><strong>Question 10</strong><span></span></div>
#   </div>
#   <div class='ch04-homework-actions'>
#     <button type='button' id='ch04-homework-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch04-homework-reset'>Clear Results</button>
#     <span class='ch04-homework-result' id='ch04-homework-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var homeworkId = 'ch04-homework';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var codeMirror = cell.querySelector('.CodeMirror');
#     if (codeMirror && codeMirror.CodeMirror && typeof codeMirror.CodeMirror.getValue === 'function') {
#       return codeMirror.CodeMirror.getValue();
#     }
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent) {
#       return Array.from(cmContent.querySelectorAll('.cm-line')).map(function (line) { return line.textContent; }).join('\n');
#     }
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.from(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 6)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function collectAnswers() {
#     var answers = {};
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var selected = document.querySelector('input[name=ch02-hw-' + question + ']:checked');
#       answers[question] = selected ? selected.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(panel, feedback) {
#     var list = panel.querySelector('.ch04-homework-feedback-list');
#     if (list) list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10'].forEach(function (question) {
#       var row = panel.querySelector('[data-question=' + question + ']');
#       var message = row ? row.querySelector('span') : null;
#       var item = feedback ? feedback[question] : null;
#       if (!row || !message || !item) return;
#       row.classList.remove('correct', 'incorrect');
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(panel) {
#     var list = panel.querySelector('.ch04-homework-feedback-list');
#     if (list) list.hidden = true;
#     panel.querySelectorAll('.ch04-homework-feedback-row').forEach(function (row) {
#       row.classList.remove('correct', 'incorrect');
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/homework-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var saved = text ? JSON.parse(text) : null;
#         if (!response.ok || !saved || !saved.ok) throw new Error(saved && (saved.message || saved.error) ? (saved.message || saved.error) : 'Submission API is unavailable.');
#         return saved;
#       });
#     });
#   }
#
#   function initHomeworkSubmit() {
#     var panel = document.getElementById('ch04-homework-submit-panel');
#     if (!panel || panel.dataset.ready === 'true') return;
#     panel.dataset.ready = 'true';
#
#     var identity = getParams();
#     var result = document.getElementById('ch04-homework-result');
#     var submit = document.getElementById('ch04-homework-submit');
#     var actions = panel.querySelector('.ch04-homework-actions');
#     var reset = document.getElementById('ch04-homework-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(panel);
#       result.textContent = 'Submitting homework.';
#       submit.disabled = true;
#       saveAttempt({
#         homework_id: homeworkId,
#         answers: collectAnswers(),
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           if (payload.feedback) applyFeedback(panel, payload.feedback);
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(panel);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initHomeworkSubmit);
#   } else {
#     initHomeworkSubmit();
#   }
# })();
# </script>
