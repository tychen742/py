# %% [markdown]
# # Homework
#
# - Use these questions after class to check your understanding of the chapter concepts and coding skills.
# - Sign in from the account menu before you start working on the homework.
# - Complete all true/false and coding questions before you submit the homework.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.
#
# <style>
# .tf-options { display: flex; gap: 1.25rem; flex-wrap: wrap; margin: 0.4rem 0 0.15rem; font-size: inherit !important; }
# .tf-options label { display: inline-flex; align-items: center; gap: 0.35rem; cursor: pointer; font-size: inherit !important; font-weight: 400 !important; line-height: 1.4; }
# .tf-options input { margin: 0; }
# .cell:has(.tf-options) { margin-bottom: 0.1rem; }
# .cell:has(.tf-options) + .cell { margin-top: 0; margin-bottom: 1.65rem; }
# .cell:has(.tf-options) + .cell details { margin-top: 0; }
# </style>
#
# <div data-assignment-answers="ch02-homework"></div>

# %% [markdown]
# ::::{div} assignment-question-card
#
# **1. Variables**
#
# A data team stores the current file name in `source_file` and the number of rows in `row_count`. Those variable names make the script easier to read than names such as `x` and `y`.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 1 answer">
#   <label><input type="radio" name="ch02-hw-q1" value="true"> True</label>
#   <label><input type="radio" name="ch02-hw-q1" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Descriptive variable names help readers understand what each value represents.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **2. Type Conversion**
#
# A web form sends the string `"42"` for a response count. Python can always use that string directly in numeric addition without conversion.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 2 answer">
#   <label><input type="radio" name="ch02-hw-q2" value="true"> True</label>
#   <label><input type="radio" name="ch02-hw-q2" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# Text input normally needs int() or float() before numeric addition.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **3. Numeric Operators**
#
# When a report needs whole hours and leftover minutes from a count of seconds, integer division and the remainder operator can help separate the parts.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 3 answer">
#   <label><input type="radio" name="ch02-hw-q3" value="true"> True</label>
#   <label><input type="radio" name="ch02-hw-q3" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# // gives a whole-number quotient and % gives the remainder.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **4. Boolean Expressions**
#
# A dashboard rule such as `score >= 80 and account_active` produces a Boolean value that can represent whether a record is eligible.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 4 answer">
#   <label><input type="radio" name="ch02-hw-q4" value="true"> True</label>
#   <label><input type="radio" name="ch02-hw-q4" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Comparisons and logical operators produce Boolean results.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **5. Collection Types**
#
# A tuple is the best basic collection type when a program must repeatedly append new daily sales values to the same object.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 5 answer">
#   <label><input type="radio" name="ch02-hw-q5" value="true"> True</label>
#   <label><input type="radio" name="ch02-hw-q5" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# Lists are mutable and fit repeated appends better than tuples.

# %%
### 6. Format a report line
# Use the variables below to print exactly:
# Report: sales has 128 rows and 5 columns
report_name = "sales"
row_count = 128
column_count = 5

### Your code starts here.



### Your code ends here.

# %%
### Solution
report_name = "sales"
row_count = 128
column_count = 5

print(f"Report: {report_name} has {row_count} rows and {column_count} columns")
# Out:
# Report: sales has 128 rows and 5 columns

# %%
### 7. Convert seconds to time parts
# Use numeric operators to split total_seconds into hours, minutes, and seconds.
# Print exactly these three lines:
# Hours: 3
# Minutes: 28
# Seconds: 20
total_seconds = 12500

### Your code starts here.



### Your code ends here.

# %%
### Solution
total_seconds = 12500

hours = total_seconds // 3600
remaining_seconds = total_seconds % 3600
minutes = remaining_seconds // 60
seconds = remaining_seconds % 60

print("Hours:", hours)
print("Minutes:", minutes)
print("Seconds:", seconds)
# Out:
# Hours: 3
# Minutes: 28
# Seconds: 20

# %%
### 8. Convert text prices
# Convert the two text prices to floating-point numbers.
# Calculate total and round it to two decimal places.
# Print exactly these three lines:
# Total: 25.49
# First price type: <class 'float'>
# Total type: <class 'float'>
base_price_text = "19.99"
fee_text = "5.50"

### Your code starts here.



### Your code ends here.

# %%
### Solution
base_price_text = "19.99"
fee_text = "5.50"

base_price = float(base_price_text)
fee = float(fee_text)
total = round(base_price + fee, 2)

print("Total:", total)
print("First price type:", type(base_price))
print("Total type:", type(total))
# Out:
# Total: 25.49
# First price type: <class 'float'>
# Total type: <class 'float'>

# %%
### 9. Slice a code string
# Use indexing, slicing, and len() with the code below.
# Print exactly these four lines:
# Prefix: PY
# Year: 2026
# Label: LAB
# Code length: 11
course_code = "PY-2026-LAB"

### Your code starts here.



### Your code ends here.

# %%
### Solution
course_code = "PY-2026-LAB"

prefix = course_code[0:2]
year = course_code[3:7]
label = course_code[-3:]

print("Prefix:", prefix)
print("Year:", year)
print("Label:", label)
print("Code length:", len(course_code))
# Out:
# Prefix: PY
# Year: 2026
# Label: LAB
# Code length: 11

# %%
### 10. Summarize a small collection
# Use the list and dictionary below.
# Create unique_names as a sorted list of unique names.
# Create bob_pair as a tuple with "Bob" and Bob's score.
# Print exactly these four lines:
# Submission count: 4
# Unique names: ['Ana', 'Bob', 'Chen']
# Bob score: 88
# Bob pair: ('Bob', 88)
names = ["Ana", "Bob", "Ana", "Chen"]
scores = {"Ana": 91, "Bob": 88, "Chen": 95}

### Your code starts here.



### Your code ends here.

# %%
### Solution
names = ["Ana", "Bob", "Ana", "Chen"]
scores = {"Ana": 91, "Bob": 88, "Chen": 95}

unique_names = sorted(set(names))
bob_pair = ("Bob", scores["Bob"])

print("Submission count:", len(names))
print("Unique names:", unique_names)
print("Bob score:", scores["Bob"])
print("Bob pair:", bob_pair)
# Out:
# Submission count: 4
# Unique names: ['Ana', 'Bob', 'Chen']
# Bob score: 88
# Bob pair: ('Bob', 88)

# %% [markdown]
# <style>
# .ch02-homework-submit { max-width: 900px; margin-top: 1rem; }
# .ch02-homework-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch02-homework-feedback-list[hidden] { display: none; }
# .ch02-homework-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch02-homework-feedback-row strong { margin-right: 0.35rem; }
# .ch02-homework-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch02-homework-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch02-homework-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch02-homework-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch02-homework-actions button.secondary { background: white; color: #176de8; }
# .ch02-homework-actions.is-locked { opacity: 0.55; }
# .ch02-homework-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch02-homework-result { font-weight: 700; }
# </style>
#
# <div class='ch02-homework-submit' id='ch02-homework-submit-panel'>
#   <div class='ch02-homework-feedback-list' aria-live='polite' hidden>
#     <div class='ch02-homework-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch02-homework-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch02-homework-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch02-homework-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch02-homework-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#     <div class='ch02-homework-feedback-row' data-question='q6'><strong>Question 6</strong><span></span></div>
#     <div class='ch02-homework-feedback-row' data-question='q7'><strong>Question 7</strong><span></span></div>
#     <div class='ch02-homework-feedback-row' data-question='q8'><strong>Question 8</strong><span></span></div>
#     <div class='ch02-homework-feedback-row' data-question='q9'><strong>Question 9</strong><span></span></div>
#     <div class='ch02-homework-feedback-row' data-question='q10'><strong>Question 10</strong><span></span></div>
#   </div>
#   <div class='ch02-homework-actions'>
#     <button type='button' id='ch02-homework-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch02-homework-reset'>Clear Results</button>
#     <span class='ch02-homework-result' id='ch02-homework-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var homeworkId = 'ch02-homework';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var codeMirror = cell.querySelector('.CodeMirror');
#     if (codeMirror && codeMirror.CodeMirror && typeof codeMirror.CodeMirror.getValue === 'function') {
#       return codeMirror.CodeMirror.getValue();
#     }
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent) {
#       return Array.from(cmContent.querySelectorAll('.cm-line')).map(function (line) { return line.textContent; }).join('\n');
#     }
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.from(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 6)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function collectAnswers() {
#     var answers = {};
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var selected = document.querySelector('input[name=ch02-hw-' + question + ']:checked');
#       answers[question] = selected ? selected.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(panel, feedback) {
#     var list = panel.querySelector('.ch02-homework-feedback-list');
#     if (list) list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10'].forEach(function (question) {
#       var row = panel.querySelector('[data-question=' + question + ']');
#       var message = row ? row.querySelector('span') : null;
#       var item = feedback ? feedback[question] : null;
#       if (!row || !message || !item) return;
#       row.classList.remove('correct', 'incorrect');
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(panel) {
#     var list = panel.querySelector('.ch02-homework-feedback-list');
#     if (list) list.hidden = true;
#     panel.querySelectorAll('.ch02-homework-feedback-row').forEach(function (row) {
#       row.classList.remove('correct', 'incorrect');
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/homework-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var saved = text ? JSON.parse(text) : null;
#         if (!response.ok || !saved || !saved.ok) throw new Error(saved && (saved.message || saved.error) ? (saved.message || saved.error) : 'Submission API is unavailable.');
#         return saved;
#       });
#     });
#   }
#
#   function initHomeworkSubmit() {
#     var panel = document.getElementById('ch02-homework-submit-panel');
#     if (!panel || panel.dataset.ready === 'true') return;
#     panel.dataset.ready = 'true';
#
#     var identity = getParams();
#     var result = document.getElementById('ch02-homework-result');
#     var submit = document.getElementById('ch02-homework-submit');
#     var actions = panel.querySelector('.ch02-homework-actions');
#     var reset = document.getElementById('ch02-homework-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(panel);
#       result.textContent = 'Submitting homework.';
#       submit.disabled = true;
#       saveAttempt({
#         homework_id: homeworkId,
#         answers: collectAnswers(),
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           if (payload.feedback) applyFeedback(panel, payload.feedback);
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(panel);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initHomeworkSubmit);
#   } else {
#     initHomeworkSubmit();
#   }
# })();
# </script>
