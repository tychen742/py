# %% [markdown]
# # Python Built-In Functions

# %%
import sys
from pathlib import Path

# Find project root by looking for _config.yml
current = Path.cwd()
for parent in [current, *current.parents]:
    if (parent / '_config.yml').exists():
        project_root = parent
        break
else:
    project_root = Path.cwd().parent.parent

# Add project root to path
sys.path.insert(0, str(project_root))

# Import shared teaching helpers and cell magics
from shared import thinkpython, diagram, jupyturtle, structshape
from shared.download import download

# %% [markdown]
# In Python, **built-in functions** and **built-in modules** are both part of the standard tools the language gives you, but they serve different purposes. Built-in functions are ready to use without `import`. They are automatically available in the Python context. Modules, on the other hand, need to be imported to use. For functionalities that Python does not provide, we either
#
# 1. Find a third-party **package** (module or library) that has the functions, install the package to use the contained functions, or
# 2. Write user-defined **custom functions**.

# %% [markdown]
# ## Common Built-in Functions
#
# Python has 71 (built-in functions)[https://docs.python.org/3/library/functions.html]  available for use without **import**. The table below lists a compact working set for beginning Python programmers.
#
# | Function | Purpose |
# |---|---|
# | `print()` | display output |
# | `type()` | inspect an object's type |
# | `len()` | count items in a sequence or collection |
# | `round()` | round a number |
# | `abs()` | absolute value |
# | `min()`, `max()` | smallest or largest value |
# | `sum()` | add numeric values |
# | `sorted()` | return a sorted list |
# | `input()` | read text from a user in interactive programs |

# %%
scores = [88, 92, 75, 100, 83]
print(len(scores))
print(min(scores), max(scores))
print(sum(scores) / len(scores))
print(sorted(scores))
# Out:
# 5
# 75 100
# 87.6
# [75, 83, 88, 92, 100]

# %% [markdown]
# Some functions return values you can store and reuse. Other functions, such as `print()`, display output but return `None`.

# %%
rounded_average = round(sum(scores) / len(scores), 1)
print(rounded_average)

return_value = print("display only")
print(return_value)
# Out:
# 87.6
# display only
# None

# %% [markdown]
# ## Built-in Functions
#
# In the [Python Standard Library](https://docs.python.org/3/library/index.html), you can find all the Python built-in functions listed:
#
# ```{figure} ../../figures/python-builtin-functions.png
# ---
# width: 400px
# name: python-builtin-functions
# ---
# [Python Built-In Functions](https://docs.python.org/3/library/functions.html#built-in-functions)
# ```

# %% [markdown]
# The 71 Python built-in functions can be grouped by purpose.
#
# | # | Group             | Functions          | Notes                  |
# |-| ------------------------------- | ---------------------------------------------------------------------------------------------------------------------------------- | ---------------------------------------------------------------- |
# |1| Numbers & math                  | `abs`, `divmod`, `max`, `min`, `pow`, `round`, `sum`                                                                               | `pow(a, b, mod=None)` supports modular exponentiation.           |
# |2| Type construction/conversion | **`bool`**, **`int`**, **`float`**, `complex`, **`str`**, `bytes`, `bytearray`, `memoryview`, **`list`**, **`tuple`**, `set`, `frozenset`, **`dict`**, **`range`** | Convert or construct core types.                                 |
# |3| Object/attribute introspection  | **`type`**, **`isinstance`**, `issubclass`, **`id`**, `hash`, `dir`, `vars`, `repr`, `ascii`                                                   | `vars(obj)` → `obj.__dict__` when available.                     |
# |4| Attribute access                | `getattr`, `setattr`, `delattr`, `hasattr`                                                                                         | Dynamic attribute management.                                    |
# |5| Iteration & functional tools    | `iter`, `next`, **`enumerate`**, `zip`, `map`, `filter`, `sorted`, `reversed`                                                          | Prefer comprehensions when clearer.                              |
# |6| Sequence/char helpers           | **`len`**, `ord`, `chr`, `slice`                                                                                                       | `len()` works on many containers.                                |
# |7| I/O                             | **`print`**, **`input`**, `open`                                                                                                           | `open` returns a context manager; prefer `with open(...) as f:`. |
# |8| Formatting / representation     | `format`, `bin`, `oct`, `hex`                                                                                                      | Also see f-strings for formatting.                               |
# |9| Object model (OOP helpers)      | `object`, `property`, `classmethod`, `staticmethod`, `super`                                                                       | Define descriptors and class behaviors.                          |
# |10| Execution / metaprogramming     | `compile`, `eval`, `exec`                                                                                                          | Use with care; security concerns for untrusted input.            |
# |11| Environment / namespaces        | `globals`, `locals`                                                                                                                | Introspection of current namespaces.                             |
# |12| Help/debugging                  | `help`, `breakpoint`                                                                                                               | `breakpoint()` respects `PYTHONBREAKPOINT`.                      |
# |13| Import                          | `__import__`                                                                                                                       | Low-level import; usually use `import` statement instead.        |

# %% [markdown]
# ### More Functions
#
# But Python has more than the built-in functions listed above. Let's look at arithmetic/math functions as an example. You see that Python provides three groups of arithmetic **functions**:
# 1. The 71 **built-in** functions
# 2. **`math`** module functions
# 3. **`operator`** module functions

# %% [markdown]
# Common math functions are built-ins.

# %%
abs(-7)          # 7
round(3.14159, 2) # 3.14
pow(2, 10)       # 1024
divmod(17, 5)    # (3, 2)
sum([1, 2, 3])   # 6
min(4, 2, 9)     # 2
max([4, 2, 9])   # 9
# Out:
# 9

# %% [markdown]
# Other math functions that are not built in can be made available by importing `math`. The table below compares built-in math functions with those imported from the `math` module.

# %% [markdown]
# | Category | Built-in (always available) | `math` module (needs import) |  Purpose   | Example        |    |      |
# |---|---|---| ----------------------- | ---------------|----|------ |
# | Absolute value | `abs(x)` | — |
# | Power | `pow(x, y)` or `x ** y` | `math.pow(x, y)` (always returns float) |
# | Rounding | `round(x, n)` | `math.floor(x)`, `math.ceil(x)` | Round down, Round up | `math.floor(3.9)` | → | `3`     |
# | Sum/min/max | `sum()`, `min()`, `max()` | — |
# | Square root | — | `math.sqrt(x)` | Square root             | `math.sqrt(16)` | →  | `4.0`   |
# | Trigonometry | — | `math.sin()`, `math.cos()`, `math.tan()` |
# | Logarithms | — | `math.log()`, `math.log10()`, `math.log2()` |
# | Constants | — | `math.pi`, `math.e`, `math.inf`, `math.nan` |
# | Factorial | — | `math.factorial(n)` | Factorial               | `math.factorial(5)` | → | `120` |
# | Finite number | — | `math.isfinite(x)`    | Finite number?          | `math.isfinite(2)` | → | `True` |
# | Product | — | `math.prod(iterable)` | Multiply all items      | `math.prod([2, 3, 4])` | → | `24` |

# %% [markdown]
# The **`operator`** module provides the **function version** of the same operations as the built-in arithmetic operators (`+`, `-`, `==`, `<`, etc.). The difference between `operator` math functions and the built-in math operators is that you can pass them around whenever a function is expected.

# %%
import operator
operator.add(3, 2)       # 5
operator.sub(3, 2)       # 1
# Out:
# 1

# %%
# %%expect SyntaxError
#
# # This doesn't work — + is not a value you can pass
# sorted([3,1,2], key=+)   # SyntaxError
#
# # This works — operator.add is a real function object
# from functools import reduce
# reduce(operator.add, [1, 2, 3, 4])   # 10
# Out:
#   Cell In[14], line 2
#     sorted([3,1,2], key=+)   # SyntaxError
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ```{index} argument
# ```
#
# ## Arguments
#
# When you call a function, the expressions inside the parentheses are called **arguments**. For example:

# %%
import math

int('101')           ### take one argument
math.pow(5, 2)       ### take two
int('101', 2)        ### take additional optional arguments, such as base 2 here
round(math.pi, 3)    ### takes an optional second argument, **decimal places** 
print('Any', 'number', 'of', 'arguments')   ### multiple arguments
# Out:
# Any number of arguments

# %% [markdown]
# ## Return Values
#
# When you call built-in functions such as `abs`, `round`, `sqrt`, and `pow`, they return a value you can assign to a variable or use as part of an expression.
#
# Some use the `print` function to display values, but they don't return values we assign to variables or use in expressions.

# %%
import math

math.sqrt(42 / math.pi)            ### returns value
# Out:
# 3.656366395715726

# %%
radius = math.sqrt(42 / math.pi)    ### assign to variable
radius
# Out:
# 3.656366395715726

# %% [markdown]
# If a function doesn't have a `return` statement, it returns **`None`**, which is a special value like `True` and `False`.

# %% [markdown]
# You have used the `print` function to display a string, but it does not use a `return` statement to return a value. If we assign the result to a variable, it still displays the string.

# %%
print(print())   ### returns None
# Out:
# None
