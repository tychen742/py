# %% [markdown]
# ```{figure} ../images/10-data-structures-bbg.png
# :alt: 10-data-structures-bbg.png
# :name: 10-data-structures-bbg.png
# :align: center
# :width: 50%
#
# 10 Data Structures You Use Daily ([bytebytego](https://blog.bytebytego.com/p/ep187-10-key-data-structures-we-use?utm_source=post-email-title&publication_id=817132&post_id=177690588&utm_campaign=email-post-title&isFreemail=true&r=6girkv&triedRedirect=true&utm_medium=email))
