# %% [markdown]
# # Dictionaries and Mapping

# %% [markdown]
# Dictionaries are mapping containers for fast lookup, record-like data, counting, grouping, and key-value relationships.
#
# - Dictionaries map keys to values
# - Keys must be hashable so Python can locate values efficiently
# - Dictionary methods support lookup, mutation, iteration, and transformation
# - Comprehensions build dictionaries from existing data
# - Lookup-heavy programs often depend on dictionary design

# %% [markdown]
# <h2>Video</h2>
#
# <iframe width="560" height="315"
# src="https://www.youtube-nocookie.com/embed/daefaLgNkw0"
#   frameborder="0"
#   allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture"
#   allowfullscreen
#   referrerpolicy="strict-origin-when-cross-origin"></iframe>
#
# > *[Python Tutorial for Beginners 5: Dictionaries](https://www.youtube.com/watch?v=daefaLgNkw0) by Corey Schafer*

# %% [markdown]
# <h2>Learning Goals</h2>
#
# By the end of this chapter, you will be able to:
#
# 1. Create, access, update, and delete entries in a Python dictionary
# 2. Use dictionary methods such as `.get()`, `.keys()`, `.values()`, `.items()`, and `.update()`
# 3. Write dictionary comprehensions and choose clear key-value structures
# 4. Use dictionary patterns for counting, grouping, inversion, and sorted summaries
# 5. Explain why dictionaries depend on hashable values

# %% [markdown]
# <h2>Chapter Flow</h2>
#
# ```{tableofcontents}
# ```

# %% [markdown]
# <h2>Glossary</h2>
#
# | # | Term | Explanation |
# |---:|---|---|
# | 1 | Dictionary | A mutable mapping that stores key-value pairs. |
# | 2 | Mapping | A collection that connects each key to a corresponding value. |
# | 3 | Key | The object used to look up a value in a dictionary. |
# | 4 | Value | The object stored under a key in a dictionary. |
# | 5 | Key-value pair | One association between a key and its value. |
# | 6 | Hashable | Describes an object that can be used as a dictionary key because its hash value is stable. |
# | 7 | Lookup | Retrieving a value by using its key. |
# | 8 | Membership testing | Checking whether a key is present in a dictionary. |
# | 9 | Adding/updating | Changing a dictionary by adding a new key-value pair or overwriting an existing value. |
# | 10 | Delete items | Removing key-value pairs from a dictionary when they are no longer needed. |
# | 11 | Common dictionary operations | Repeated dictionary tasks such as reading, adding, updating, deleting, and iterating. |
# | 12 | `get` | A dictionary method that retrieves a value and can return a default when the key is missing. |
# | 13 | `items` | A dictionary method that provides key-value pairs for iteration. |
# | 14 | Dictionary comprehension | A compact expression for building a dictionary from an iterable. |
# | 15 | `value_counts` | A counting function that returns how many times each value appears. |
# | 16 | `Counter` | A `dict` subclass from `collections` designed for counting hashable values. |
# | 17 | `defaultdict` | A `dict` subclass from `collections` that creates default values for missing keys. |
# | 18 | Inverting a dictionary | Building a new dictionary that swaps the role of keys and values. |
# | 19 | Sorting by value | Ordering dictionary entries using their values rather than their keys. |
# | 20 | Tuple key | A tuple used as a compound dictionary key. |

# %% [markdown]
# <h2><a href="overview.html" target="_blank" style="color: var(--pst-color-link, #176de8);">Chapter Overview Slides</a></h2>
