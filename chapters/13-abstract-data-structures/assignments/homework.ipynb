# %% [markdown]
# # Homework
#
# - Use these questions after class to check your understanding of the chapter concepts and coding skills.
# - Sign in from the account menu before you start working on the homework.
# - Complete all true/false and coding questions before you submit the homework.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.
#
# <style>
# .tf-options { display: flex; gap: 1.25rem; flex-wrap: wrap; margin: 0.4rem 0 0.15rem; font-size: inherit !important; }
# .tf-options label { display: inline-flex; align-items: center; gap: 0.35rem; cursor: pointer; font-size: inherit !important; font-weight: 400 !important; line-height: 1.4; }
# .tf-options input { margin: 0; }
# .cell:has(.tf-options) { margin-bottom: 0.1rem; }
# .cell:has(.tf-options) + .cell { margin-top: 0; margin-bottom: 1.65rem; }
# .cell:has(.tf-options) + .cell details { margin-top: 0; }
# </style>
#
# <div data-assignment-answers="ch13-homework"></div>

# %% [markdown]
# ::::{div} assignment-question-card
#
# **1. Stacks**
#
# Undo history is naturally modeled as a stack because the most recent action is removed first.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 1 answer">
#   <label><input type="radio" name="ch13-hw-q1" value="true"> True</label>
#   <label><input type="radio" name="ch13-hw-q1" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# This workplace case matches the chapter concept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **2. Queues**
#
# A service line is naturally modeled as a queue because the earliest arrival should usually be served first.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 2 answer">
#   <label><input type="radio" name="ch13-hw-q2" value="true"> True</label>
#   <label><input type="radio" name="ch13-hw-q2" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# This workplace case matches the chapter concept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **3. Trees**
#
# A tree node can have any number of parents and still remain a tree.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 3 answer">
#   <label><input type="radio" name="ch13-hw-q3" value="true"> True</label>
#   <label><input type="radio" name="ch13-hw-q3" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# The case reverses or overstates the chapter concept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **4. Graphs**
#
# Course prerequisites can be represented as a graph because courses can connect to other courses through dependency relationships.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 4 answer">
#   <label><input type="radio" name="ch13-hw-q4" value="true"> True</label>
#   <label><input type="radio" name="ch13-hw-q4" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# This workplace case matches the chapter concept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **5. ADT Interfaces**
#
# An abstract data type is defined mainly by the exact variable names used inside its implementation.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 5 answer">
#   <label><input type="radio" name="ch13-hw-q5" value="true"> True</label>
#   <label><input type="radio" name="ch13-hw-q5" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# The case reverses or overstates the chapter concept.

# %%
### 6. Use a stack
# Push three pages and pop the most recent page. Print exactly these two lines:
# # Back to: checkout
# # Remaining stack: ['home', 'products']
history = []

### Your code starts here.



### Your code ends here.

# %%
### Solution
history = []
history.append("home")
history.append("products")
history.append("checkout")
last_page = history.pop()
print("Back to:", last_page)
print("Remaining stack:", history)
# Out:
# Back to: checkout
# Remaining stack: ['home', 'products']

# %%
### 7. Use a queue
# Serve the first customer from a list-based queue. Print exactly these two lines:
# # Served: Ana
# # Waiting: ['Bob', 'Chen']
line = ["Ana", "Bob", "Chen"]

### Your code starts here.



### Your code ends here.

# %%
### Solution
line = ["Ana", "Bob", "Chen"]
served = line.pop(0)
print("Served:", served)
print("Waiting:", line)
# Out:
# Served: Ana
# Waiting: ['Bob', 'Chen']

# %%
### 8. Represent a tree
# Use a nested dictionary for the team tree. Print exactly this line:
# # Direct reports: ['Data', 'Operations']
company = {"CEO": {"Data": {}, "Operations": {}}}

### Your code starts here.



### Your code ends here.

# %%
### Solution
company = {"CEO": {"Data": {}, "Operations": {}}}
direct_reports = list(company["CEO"].keys())
print("Direct reports:", direct_reports)
# Out:
# Direct reports: ['Data', 'Operations']

# %%
### 9. Represent a graph
# Use a dictionary of adjacency lists. Print exactly this line:
# # DS200 neighbors: ['DS300', 'ML310']
graph = {"DS100": ["DS200"], "DS200": ["DS300", "ML310"]}

### Your code starts here.



### Your code ends here.

# %%
### Solution
graph = {"DS100": ["DS200"], "DS200": ["DS300", "ML310"]}
print("DS200 neighbors:", graph["DS200"])
# Out:
# DS200 neighbors: ['DS300', 'ML310']

# %%
### 10. Run breadth-first search order
# Traverse the small graph with a queue. Print exactly this line:
# # Visit order: ['A', 'B', 'C', 'D']
graph = {"A": ["B", "C"], "B": ["D"], "C": [], "D": []}

### Your code starts here.



### Your code ends here.

# %%
### Solution
graph = {"A": ["B", "C"], "B": ["D"], "C": [], "D": []}
queue = ["A"]
seen = set()
order = []

while queue:
    node = queue.pop(0)
    if node in seen:
        continue
    seen.add(node)
    order.append(node)
    for neighbor in graph[node]:
        queue.append(neighbor)

print("Visit order:", order)
# Out:
# Visit order: ['A', 'B', 'C', 'D']

# %% [markdown]
# <style>
# .ch13-homework-submit { max-width: 900px; margin-top: 1rem; }
# .ch13-homework-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch13-homework-feedback-list[hidden] { display: none; }
# .ch13-homework-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch13-homework-feedback-row strong { margin-right: 0.35rem; }
# .ch13-homework-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch13-homework-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch13-homework-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch13-homework-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch13-homework-actions button.secondary { background: white; color: #176de8; }
# .ch13-homework-actions.is-locked { opacity: 0.55; }
# .ch13-homework-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch13-homework-result { font-weight: 700; }
# </style>
#
# <div class='ch13-homework-submit' id='ch13-homework-submit-panel'>
#   <div class='ch13-homework-feedback-list' aria-live='polite' hidden>
#     <div class='ch13-homework-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch13-homework-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch13-homework-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch13-homework-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch13-homework-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#     <div class='ch13-homework-feedback-row' data-question='q6'><strong>Question 6</strong><span></span></div>
#     <div class='ch13-homework-feedback-row' data-question='q7'><strong>Question 7</strong><span></span></div>
#     <div class='ch13-homework-feedback-row' data-question='q8'><strong>Question 8</strong><span></span></div>
#     <div class='ch13-homework-feedback-row' data-question='q9'><strong>Question 9</strong><span></span></div>
#     <div class='ch13-homework-feedback-row' data-question='q10'><strong>Question 10</strong><span></span></div>
#   </div>
#   <div class='ch13-homework-actions'>
#     <button type='button' id='ch13-homework-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch13-homework-reset'>Clear Results</button>
#     <span class='ch13-homework-result' id='ch13-homework-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var homeworkId = 'ch13-homework';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var codeMirror = cell.querySelector('.CodeMirror');
#     if (codeMirror && codeMirror.CodeMirror && typeof codeMirror.CodeMirror.getValue === 'function') {
#       return codeMirror.CodeMirror.getValue();
#     }
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent) {
#       return Array.from(cmContent.querySelectorAll('.cm-line')).map(function (line) { return line.textContent; }).join('\n');
#     }
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.from(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 6)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function collectAnswers() {
#     var answers = {};
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var selected = document.querySelector('input[name=ch02-hw-' + question + ']:checked');
#       answers[question] = selected ? selected.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(panel, feedback) {
#     var list = panel.querySelector('.ch13-homework-feedback-list');
#     if (list) list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10'].forEach(function (question) {
#       var row = panel.querySelector('[data-question=' + question + ']');
#       var message = row ? row.querySelector('span') : null;
#       var item = feedback ? feedback[question] : null;
#       if (!row || !message || !item) return;
#       row.classList.remove('correct', 'incorrect');
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(panel) {
#     var list = panel.querySelector('.ch13-homework-feedback-list');
#     if (list) list.hidden = true;
#     panel.querySelectorAll('.ch13-homework-feedback-row').forEach(function (row) {
#       row.classList.remove('correct', 'incorrect');
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/homework-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var saved = text ? JSON.parse(text) : null;
#         if (!response.ok || !saved || !saved.ok) throw new Error(saved && (saved.message || saved.error) ? (saved.message || saved.error) : 'Submission API is unavailable.');
#         return saved;
#       });
#     });
#   }
#
#   function initHomeworkSubmit() {
#     var panel = document.getElementById('ch13-homework-submit-panel');
#     if (!panel || panel.dataset.ready === 'true') return;
#     panel.dataset.ready = 'true';
#
#     var identity = getParams();
#     var result = document.getElementById('ch13-homework-result');
#     var submit = document.getElementById('ch13-homework-submit');
#     var actions = panel.querySelector('.ch13-homework-actions');
#     var reset = document.getElementById('ch13-homework-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(panel);
#       result.textContent = 'Submitting homework.';
#       submit.disabled = true;
#       saveAttempt({
#         homework_id: homeworkId,
#         answers: collectAnswers(),
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           if (payload.feedback) applyFeedback(panel, payload.feedback);
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(panel);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initHomeworkSubmit);
#   } else {
#     initHomeworkSubmit();
#   }
# })();
# </script>
