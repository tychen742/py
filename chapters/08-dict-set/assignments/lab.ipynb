# %% [markdown]
# # Ch08 Lab — Text Analysis with Dictionaries and Sets

# %% [markdown]
# ## Overview
#
# In this lab you will analyze a text file using dictionaries, sets, and `Counter` to answer questions about word usage.

# %% [markdown]
# ## Part 1 — Load and Clean *(recall)*
#
# Load any plain-text file (e.g. a Project Gutenberg book) and build a cleaned word frequency dictionary: lowercase, strip punctuation, exclude words shorter than 3 characters.

# %%
# Your solution here

# %% [markdown]
# ## Part 2 — Top Words *(application)*
#
# Use `Counter` to find the 10 most common words. Display them as a table (word, count).

# %%
# Your solution here

# %% [markdown]
# ## Part 3 — Vocabulary Overlap *(extension)*
#
# Compare the vocabulary of two different texts using set operations. Report:
# - Words unique to each text
# - Words shared by both
# - Jaccard similarity: `|A ∩ B| / |A ∪ B|`

# %%
# Your solution here
