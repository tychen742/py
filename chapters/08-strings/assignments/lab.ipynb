# %% [markdown]
# # Lab
#
# - Use this lab to practice the chapter's coding skills in runnable Python code.
# - Sign in from the account menu before you start working on the lab.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.
#
# <div data-assignment-answers="ch08-lab"></div>

# %%
### Question 1: Clean a messy title
# raw_title has extra whitespace and inconsistent case.
# Build clean_title by collapsing all whitespace to single spaces
# (join raw_title.split() with a single space) and title-casing the
# result.
# Compute word_count as the number of words in clean_title.
# Print exactly these two lines:
# Clean title: The Quick Brown Fox
# Word count: 4
raw_title = "  the Quick BROWN fox   "
### Your code starts here.



### Your code ends here.

# %%
### Solution
raw_title = "  the Quick BROWN fox   "

clean_title = " ".join(raw_title.split()).title()
word_count = len(clean_title.split())

print("Clean title:", clean_title)
print("Word count:", word_count)
# Out:
# Clean title: The Quick Brown Fox
# Word count: 4

# %%
### Question 2: Normalize a ticket code
# ticket_code has stray whitespace, a lowercase prefix, and hyphens.
# Build normalized by stripping whitespace, uppercasing, then
# replacing every "-" with "_".
# Compute is_valid as True when normalized starts with "TS".
# Compute underscore_count as the number of "_" characters in
# normalized.
# Print exactly these three lines:
# Normalized: TS_2024_ALPHA
# Valid ticket: True
# Underscore count: 2
ticket_code = "  ts-2024-Alpha  "
### Your code starts here.



### Your code ends here.

# %%
### Solution
ticket_code = "  ts-2024-Alpha  "

normalized = ticket_code.strip().upper().replace("-", "_")
is_valid = normalized.startswith("TS")
underscore_count = normalized.count("_")

print("Normalized:", normalized)
print("Valid ticket:", is_valid)
print("Underscore count:", underscore_count)
# Out:
# Normalized: TS_2024_ALPHA
# Valid ticket: True
# Underscore count: 2

# %%
### Question 3: Sort words case-insensitively
# word_list mixes upper and lower case spellings of the same words.
# Build sorted_words by sorting word_list with key=str.casefold, so
# the sort ignores case.
# Compute unique_count as the number of distinct case-folded words.
# Print exactly these two lines:
# Sorted words: ['Apple', 'apple', 'banana', 'Banana', 'cherry']
# Unique count: 3
word_list = ["banana", "Apple", "cherry", "apple", "Banana"]
### Your code starts here.



### Your code ends here.

# %%
### Solution
word_list = ["banana", "Apple", "cherry", "apple", "Banana"]

sorted_words = sorted(word_list, key=str.casefold)
unique_count = len({w.casefold() for w in word_list})

print("Sorted words:", sorted_words)
print("Unique count:", unique_count)
# Out:
# Sorted words: ['Apple', 'apple', 'banana', 'Banana', 'cherry']
# Unique count: 3

# %%
### Question 4: Extract numbers from a report line
# report is one line of a server log with numbers mixed into text.
# Import re and use re.findall(r"\d+", report) to build numbers, a
# list of the digit sequences found (as strings).
# Compute total as the sum of those numbers converted to int.
# Print exactly these two lines:
# Numbers found: ['1', '42', '2', '108']
# Total: 153
report = "Server room1 handled 42 requests and room2 handled 108 requests"
### Your code starts here.



### Your code ends here.

# %%
### Solution
report = "Server room1 handled 42 requests and room2 handled 108 requests"

import re

numbers = re.findall(r"\d+", report)
total = sum(int(n) for n in numbers)

print("Numbers found:", numbers)
print("Total:", total)
# Out:
# Numbers found: ['1', '42', '2', '108']
# Total: 153

# %%
### Question 5: Validate and split a user code
# code should match the pattern: one uppercase letter, a hyphen,
# then exactly four digits (for example "A-1234").
# Import re. Compute is_valid as a bool using
# re.fullmatch(r"[A-Z]-\d{4}", code).
# Use re.search(r"([A-Z])-(\d{4})", code) to get a match object, then
# read letter as group(1) and number as group(2).
# Print exactly these three lines:
# Valid code: True
# Letter: A
# Number: 1234
code = "A-1234"
### Your code starts here.



### Your code ends here.

# %%
### Solution
code = "A-1234"

import re

is_valid = bool(re.fullmatch(r"[A-Z]-\d{4}", code))
match = re.search(r"([A-Z])-(\d{4})", code)
letter = match.group(1)
number = match.group(2)

print("Valid code:", is_valid)
print("Letter:", letter)
print("Number:", number)
# Out:
# Valid code: True
# Letter: A
# Number: 1234

# %% [markdown]
# <style>
# .ch08-lab-grader { max-width: 900px; margin-top: 1rem; }
# .ch08-lab-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch08-lab-feedback-list[hidden] { display: none; }
# .ch08-lab-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch08-lab-feedback-row strong { margin-right: 0.35rem; }
# .ch08-lab-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch08-lab-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch08-lab-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch08-lab-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch08-lab-actions button.secondary { background: white; color: #176de8; }
# .ch08-lab-actions.is-locked { opacity: 0.55; }
# .ch08-lab-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch08-lab-result { font-weight: 700; }
# </style>
#
# <div class='ch08-lab-grader' id='ch08-lab-grader'>
#   <div class='ch08-lab-feedback-list' aria-live='polite' hidden>
#     <div class='ch08-lab-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch08-lab-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch08-lab-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch08-lab-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch08-lab-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#   </div>
#   <div class='ch08-lab-actions'>
#     <button type='button' id='ch08-lab-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch08-lab-reset'>Clear Results</button>
#     <span class='ch08-lab-result' id='ch08-lab-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var labId = 'ch08-lab';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var codeMirror = cell.querySelector('.CodeMirror');
#     if (codeMirror && codeMirror.CodeMirror && typeof codeMirror.CodeMirror.getValue === 'function') {
#       return codeMirror.CodeMirror.getValue();
#     }
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent) {
#       return Array.from(cmContent.querySelectorAll('.cm-line')).map(function (line) { return line.textContent; }).join('\n');
#     }
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.from(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 1)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function applyFeedback(grader, feedback) {
#     var list = grader.querySelector('.ch08-lab-feedback-list');
#     if (list) list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var row = grader.querySelector('[data-question=' + question + ']');
#       var message = row ? row.querySelector('span') : null;
#       var item = feedback ? feedback[question] : null;
#       if (!row || !message || !item) return;
#       row.classList.remove('correct', 'incorrect');
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(grader) {
#     var list = grader.querySelector('.ch08-lab-feedback-list');
#     if (list) list.hidden = true;
#     grader.querySelectorAll('.ch08-lab-feedback-row').forEach(function (row) {
#       row.classList.remove('correct', 'incorrect');
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/lab-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var saved = text ? JSON.parse(text) : null;
#         if (!response.ok || !saved || !saved.ok) throw new Error(saved && (saved.message || saved.error) ? (saved.message || saved.error) : 'Submission API is unavailable.');
#         return saved;
#       });
#     });
#   }
#
#   function initLabGrader() {
#     var grader = document.getElementById('ch08-lab-grader');
#     if (!grader || grader.dataset.ready === 'true') return;
#     grader.dataset.ready = 'true';
#
#     var identity = getParams();
#     var result = document.getElementById('ch08-lab-result');
#     var submit = document.getElementById('ch08-lab-submit');
#     var actions = grader.querySelector('.ch08-lab-actions');
#     var reset = document.getElementById('ch08-lab-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = 'Submitting code.';
#       submit.disabled = true;
#       saveAttempt({
#         lab_id: labId,
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           if (payload.feedback) applyFeedback(grader, payload.feedback);
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initLabGrader);
#   } else {
#     initLabGrader();
#   }
# })();
# </script>
