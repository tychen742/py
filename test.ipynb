# %%
import tkinter as tk            ### tkinter module is imported
window = tk.Tk()
window.title("Simple GUI")
window.geometry("300x200")
window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import tkinter as tk            ### tkinter module is imported
#       2 window = tk.Tk()
#       3 window.title("Simple GUI")
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/tkinter/__init__.py:38
#      35 import sys
#      36 import types
# ---> 38 import _tkinter # If this fails your Python may not be configured for Tk
#      39 TclError = _tkinter.TclError
#      40 from tkinter.constants import *
#
# ModuleNotFoundError: No module named '_tkinter'

# %%
from shared.download import download

# %%
download('https://github.com/AllenDowney/ThinkPython/raw/v3/thinkpython.py')
# Out:
# 'thinkpython.py'

# %%
from shared import diagram

# %%
# diagram.draw_box_around(2, 3, 'My Box')
import matplotlib.pyplot as plt
from shared import diagram
fig, ax = plt.subplots()
bbox = [0.2, 0.2, 0.8, 0.8]
diagram.draw_box_around(ax, [bbox])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 6
#       4 fig, ax = plt.subplots()
#       5 bbox = [0.2, 0.2, 0.8, 0.8]
# ----> 6 diagram.draw_box_around(ax, [bbox])
#       7 plt.show()
#
# File ~/workspace/py/shared/diagram.py:96, in draw_box_around(ax, bboxes, **options)
#      95 def draw_box_around(ax, bboxes, **options):
# ---> 96     bbox = Bbox.union(bboxes)
#      97     return draw_bbox(ax, padded(bbox), **options)
#
# File ~/workspace/py/.venv/lib/python3.13/site-packages/matplotlib/transforms.py:647, in BboxBase.union(bboxes)
#     645 if not len(bboxes):
#     646     raise ValueError("'bboxes' cannot be empty")
# --> 647 x0 = np.min([bbox.xmin for bbox in bboxes])
#     648 x1 = np.max([bbox.xmax for bbox in bboxes])
#     649 y0 = np.min([bbox.ymin for bbox in bboxes])
#
# AttributeError: 'list' object has no attribute 'xmin'

# %%
from shared import jupyturtle as t
t.make_turtle()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 160,75 170,75 180,75 180,85 180,95 180,85 180,75 190,75 190,95 170,95 170,75 190,75 190,95 170,95 170,75 190,75 190,95 170,95 170,75 190,75 190,95 170,95 170,75 190,75" />'
#
# <g transform="rotate(0.0,190.0,75.0) translate(190.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
t.make_turtle()

for i in range(4):
    t.forward(20)
    t.right(90)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 170,75 170,95 150,95 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
